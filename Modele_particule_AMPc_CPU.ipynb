# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

### Importation des bibliothèques ###
import math
import os
import sys
import torch
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import trackpy as tp
import functions_analyze as lib
from scipy.signal import find_peaks

# Définition de l'appareil (CPU ou GPU) pour les opérations PyTorch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device for torch operations:", device)

def force_field_inbox(coordinates_diff, distances, Req, R0, Frep, Fadh,
                      coeff_a=None, coeff_rep=None):
    """
    Calcule le champ de forces entre les cellules en prenant en compte les forces
    de répulsion et d'adhésion, selon les distances entre les cellules.

    Paramètres:
    - coordinates_diff: Tensor des différences de coordonnées entre les cellules
    - distances: Tensor des distances entre les cellules
    - Req: Rayon d'équilibre (μm)
    - R0: Rayon d'interaction maximale (μm)
    - Frep: Intensité de la force de répulsion
    - Fadh: Intensité de la force d'adhésion
    - coeff_a: Coefficient pour la force quadratique (non utilisé ici)
    - coeff_rep: Coefficient pour ajuster la force de répulsion
    """
    Rlim = 0.000001  # Limite inférieure pour éviter la division par zéro
    R = torch.norm(coordinates_diff, dim=2)  # Calcul des distances entre les cellules
    # Empêche la force de répulsion de diverger en fixant une valeur minimale pour R
    R = torch.where(R > Rlim * torch.ones(1, device=device),
                    R, Rlim * torch.ones(1, device=device)).to(device)
    
    # Calcul de la force d'adhésion (linéaire entre Req et R0)
    force = torch.where(torch.logical_and(R < R0, R > Req),
                        -((Fadh / (R0 - Req)) * R - Fadh * Req / (R0 - Req)),
                        torch.zeros_like(R)).to(device)
    
    # Calcul de la force de répulsion (proportionnelle à 1/R)
    force = torch.where(R <= Req,
                        -Frep * coeff_rep * (1 / Req - 1 / R), force).to(device)
    
    # Calcul du champ de forces résultant en sommant les contributions des autres cellules
    # On normalise les vecteurs de différence pour obtenir les directions
    force_field = torch.sum(force[:, :, None] *
                            torch.nn.functional.normalize(coordinates_diff, dim=2), axis=1)
    
    return force_field

def plot_environment(cells, camp_field, space_size, axis, iteration=None):
        """
        Trace l'environnement de simulation, y compris les positions des cellules et
        la concentration du champ de cAMP.

        Paramètres:
        - cells: Liste des cellules
        - camp_field: Objet représentant le champ de cAMP
        - space_size: Taille de l'espace de simulation
        - axis: L'axe matplotlib sur lequel tracer
        - iteration: Numéro de l'itération (utilisé pour le titre)
        """
        axis.set_xlim(0, space_size)
        axis.set_ylim(0, space_size)

        # Traçage de la carte de concentration du cAMP
        extent = [0, space_size, 0, space_size]
        cmap = plt.cm.viridis  # Palette de couleurs pour la concentration
        im = axis.imshow(camp_field.signal.T.cpu().numpy(), origin='lower', extent=extent, cmap=cmap, alpha=0.5)

        # Récupération des positions des cellules
        x = [cell.position[0].item() for cell in cells]
        y = [cell.position[1].item() for cell in cells]

        # Attribution des couleurs en fonction de la population
        colors = ['blue' if cell.pop == 'Population 1' else 'red' for cell in cells]

        # Tracé des cellules sur le graphique
        axis.scatter(x, y, s=5, color=colors, alpha=0.5, edgecolors='k')

        axis.set_xlabel('Position X (micromètres)')
        axis.set_ylabel('Position Y (micromètres)')
        axis.set_title(f'Temps: {iteration * DELTA_T:.2f} min')

def plot_camp_field(camp_field, space_size, iteration):
    """
    Trace le champ de cAMP à une itération donnée avec une échelle de couleur fixe de 0 à 15.
    """
    extent = [0, space_size, 0, space_size]
    plt.figure(figsize=(6,6))
    
    # Utilisation de vmin et vmax pour fixer l'échelle de la barre de couleur
    im = plt.imshow(camp_field.signal.cpu().numpy().T, origin='lower', extent=extent, cmap='viridis', alpha=0.8, vmin=0, vmax=10000.0)
    
    plt.title(f'Champ de cAMP à l\'itération {iteration}')
    plt.xlabel('Position X (μm)')
    plt.ylabel('Position Y (μm)')
    
    # Ajouter une barre de couleur avec une échelle fixe
    cbar = plt.colorbar(im, label='Concentration de cAMP')
    
    plt.tight_layout()
    plt.show()
    plt.close()

def plot_function(pas, Req, R0, Frep, Fadh, a, coeff_rep):
    """
    Trace les fonctions de force de répulsion et d'adhésion en fonction de la distance.

    Paramètres:
    - pas: Pas d'échantillonnage pour les distances
    - Req: Rayon d'équilibre (μm)
    - R0: Rayon d'interaction maximale (μm)
    - Frep: Intensité de la force de répulsion
    - Fadh: Intensité de la force d'adhésion
    - a: Coefficient quadratique (non utilisé ici)
    - coeff_rep: Coefficient pour ajuster la force de répulsion
    """
    # Calcul des coefficients pour les forces (non utilisés ici)
    b = (Fadh - a * (R0 ** 2 - Req ** 2)) / (R0 - Req)
    c = -Req * (a * Req + (Fadh - a * (R0 ** 2 - Req ** 2)) / (R0 - Req))

    fig, axis = plt.subplots(figsize=(6, 6))
    plt.xlim(0, R0)
    plt.ylim(-Frep, Fadh)

    # Tracé de la force de répulsion pour R entre 0 et Req
    axis.plot(np.arange(pas, Req, pas), [
              Frep * coeff_rep * (1 / Req - 1 / R) for R in np.arange(pas, Req, pas)], label='Répulsion')
    # Tracé de la force d'adhésion pour R entre Req et R0
    axis.plot(np.arange(Req, R0, pas), [
              (Fadh / (R0 - Req)) * (R - Req) for R in np.arange(Req, R0, pas)], label='Adhésion')

    plt.xlabel('Distance')
    plt.ylabel('Force')
    plt.legend()
    plt.show()

def autovel(dX, n, tau, noise, dt, persistence):
    """
    Calcule la nouvelle direction des cellules basée sur leur déplacement,
    leur direction précédente, le bruit, le temps caractéristique tau, et la persistance.

    Paramètres:
    - dX: Déplacement de la cellule
    - n: Vecteur directionnel précédent de la cellule
    - tau: Temps caractéristique pour l'alignement directionnel
    - noise: Intensité du bruit angulaire
    - dt: Pas de temps de la simulation
    - persistence: Persistance du mouvement (non utilisé ici)

    Retourne:
    - new_direction: Nouvelle direction normalisée de la cellule
    """    
    # Normalise le vecteur de déplacement
    dX_norm = torch.nn.functional.normalize(dX, dim=1) * 0.9999999
    if persistence == 1:
        persistence = 0.9999999
    # Calcule l'angle actuel du déplacement
    theta = torch.atan2(dX_norm[:, 1], dX_norm[:, 0]).to(device)
    
    # Calcule le changement d'angle basé sur le vecteur d'orientation précédent
    dtheta = torch.arcsin((n[:, 0] * dX_norm[:, 1] - n[:, 1] * dX_norm[:, 0])) * dt / tau

    # Génère du bruit aléatoire pour la perturbation de l'angle
    rnd = (2 * math.pi * (torch.rand(len(dX), 1, device=device) - 0.5)) * noise * np.sqrt(dt)
    
    # Mise à jour de l'angle
    theta_update = theta + dtheta + rnd.squeeze(1)

    # Calcule la nouvelle direction à partir de l'angle mis à jour
    new_dir_x = torch.cos(theta_update)
    new_dir_y = torch.sin(theta_update)
    
    # Crée un nouveau tenseur pour la direction mise à jour
    new_direction = torch.stack((new_dir_x, new_dir_y), dim=1)
    
    return new_direction

def compute_local_gradient(signal_grid, position, grid_resolution, r_sensing):
    """
    Calcule le gradient local du cAMP à la position donnée.

    Paramètres:
    - signal_grid: Grille de concentration du cAMP
    - position: Position de la cellule
    - grid_resolution: Résolution de la grille (taille d'une cellule de la grille)
    - r_sensing: Rayon de détection du gradient par la cellule

    Retourne:
    - grad: Vecteur gradient du cAMP à la position de la cellule
    """
    x_idx = int(position[0].item() / grid_resolution) % signal_grid.shape[0]
    y_idx = int(position[1].item() / grid_resolution) % signal_grid.shape[1]
    grid_size_x, grid_size_y = signal_grid.shape

    # Déterminer le nombre de mailles correspondant au rayon de détection
    n_cells = int(r_sensing / grid_resolution)

    grad_x = 0.0
    grad_y = 0.0
    count = 0

    # Parcourir les positions dans la zone de détection
    for dx in range(-n_cells, n_cells + 1):
        for dy in range(-n_cells, n_cells + 1):
            distance = math.hypot(dx * grid_resolution, dy * grid_resolution)
            if 0 < distance <= r_sensing:
                x_neighbor = (x_idx + dx) % grid_size_x
                y_neighbor = (y_idx + dy) % grid_size_y

                # Calcul de la différence de concentration
                delta_c = signal_grid[x_neighbor, y_neighbor] - signal_grid[x_idx, y_idx]

                # Calcul du vecteur directionnel vers le voisin
                unit_vector = torch.tensor([dx * grid_resolution, dy * grid_resolution], device=device) / distance

                # Ajout de la contribution au gradient
                grad_x += delta_c * unit_vector[0]
                grad_y += delta_c * unit_vector[1]
                count += 1

    if count > 0:
        grad_x /= count
        grad_y /= count

    grad = torch.tensor([grad_x, grad_y], device=device)
    return grad

class CellAgent:
    def __init__(self, id, pop, position, velocity,
                 velocity_magnitude, persistence, space_size,
                 tau, noise, cell_params, sensitivity_cAMP_threshold):
        """
        Classe représentant une cellule individuelle dans la simulation.

        Paramètres:
        - id: Identifiant unique de la cellule
        - pop: Type de population (e.g., 'Population 1' ou 'Population 2')
        - position: Position initiale de la cellule (tensor)
        - velocity: Vitesse initiale de la cellule (tensor)
        - velocity_magnitude: Norme de la vitesse initiale
        - persistence: Persistance du mouvement
        - space_size: Taille de l'espace de simulation
        - tau: Temps caractéristique pour l'alignement directionnel
        - noise: Intensité du bruit dans la direction
        - cell_params: Dictionnaire des paramètres pour le modèle de FitzHugh-Nagumo
        - sensitivity_cAMP_threshold: Seuil de sensibilité au cAMP
        """
        self.id = id  # ID unique de la cellule
        self.pop = pop  # Type de population
        self.position_init = position.clone().to(device)  # Position initiale (pour référence)
        self.position = position.clone().to(device)  # Position actuelle
        self.velocity = velocity.clone().to(device)  # Vitesse actuelle
        self.velocity_magnitude = velocity_magnitude  # Norme de la vitesse
        self.persistence = persistence  # Persistance du mouvement
        self.space_size = space_size  # Taille de l'espace
        self.tau = tau  # Temps caractéristique pour l'alignement directionnel
        self.noise = noise  # Intensité du bruit
        self.direction = torch.nn.functional.normalize(velocity, p=2, dim=0)  # Direction normalisée
        # États A et R pour le modèle de FitzHugh-Nagumo
        self.A = torch.tensor(0.5, device=device)  # État de l'activateur A
        self.R = torch.tensor(0.5, device=device)  # État du répresseur R
        self.cell_params = cell_params  # Paramètres du modèle de FitzHugh-Nagumo
        # Paramètres pour la production du cAMP
        self.D = cell_params['D']  # Taux de production de cAMP
        self.a0 = cell_params['a0']  # Production basale de cAMP
        self.af = cell_params['af']  # Seuil d'activation pour la production de cAMP
        self.sensitivity_threshold = sensitivity_cAMP_threshold  # Seuil de sensibilité au cAMP

    def update_state(self, signal_value, dt):
        """
        Met à jour les états internes A et R de la cellule en fonction du signal cAMP local.

        Paramètres:
        - signal_value: Valeur du signal cAMP à la position de la cellule
        - dt: Pas de temps de la simulation
        """
        # Extraction des paramètres du modèle
        a = self.cell_params['a']
        Kd = self.cell_params['Kd']
        gamma = self.cell_params['gamma']
        c0 = self.cell_params['c0']
        epsilon = self.cell_params['epsilon']
        sigma = self.cell_params['sigma']
        noise_flag = self.cell_params.get('noise', True)

        # Calcul de l'entrée I_S en fonction du signal cAMP local
        I_S = a * torch.log1p(signal_value / Kd)

        # Mise à jour de l'état A (activateur)
        dA = (self.A - (self.A ** 3) / 3 - self.R + I_S) * dt
        if noise_flag:
            dA += sigma * math.sqrt(dt) * torch.randn((), device=device)  # Ajout de bruit
        self.A += dA

        # Mise à jour de l'état R (répresseur)
        dR = (self.A - gamma * self.R + c0) * epsilon * dt
        self.R += dR

class Population:
    def __init__(self, num_cells, space_size, velocity_magnitude,
                 persistence, min_distance, pop_tag, ecart_type,
                 tau, noise, cell_params, sensitivity_cAMP_threshold):
        """
        Classe représentant une population de cellules.

        Paramètres:
        - num_cells: Nombre de cellules dans la population
        - space_size: Taille de l'espace de simulation
        - velocity_magnitude: Norme moyenne de la vitesse des cellules
        - persistence: Persistance du mouvement
        - min_distance: Distance minimale entre les cellules à l'initialisation
        - pop_tag: Identifiant de la population (e.g., 'Population 1')
        - ecart_type: Écart-type pour la distribution des vitesses
        - tau: Temps caractéristique pour l'alignement directionnel
        - noise: Intensité du bruit dans la direction
        - cell_params: Dictionnaire des paramètres pour le modèle de FitzHugh-Nagumo
        - sensitivity_cAMP_threshold: Seuil de sensibilité au cAMP
        """
        self.num_cells = num_cells
        self.space_size = space_size
        self.velocity_magnitude = velocity_magnitude
        self.persistence = persistence
        self.min_distance = min_distance
        self.pop_tag = pop_tag  # Identifiant de la population
        self.ecart_type = ecart_type  # Écart-type pour les vitesses initiales
        self.tau = tau
        self.noise = noise
        self.cell_params = cell_params
        self.sensitivity_cAMP_threshold = sensitivity_cAMP_threshold
        self.cells = []
        self.initialize_cells()

    def initialize_cells(self):
        """
        Initialise les cellules de la population en leur attribuant des positions
        et des vitesses initiales, tout en respectant la distance minimale entre elles.
        """
        global cell_id_counter  # Compteur global pour les identifiants de cellules
        # Génération de positions aléatoires dans l'espace
        positions = torch.rand((self.num_cells, 2), device=device) * self.space_size
        # Génération de directions aléatoires normalisées
        directions = torch.nn.functional.normalize(torch.empty_like(positions).uniform_(-1, 1), dim=1)
        # Génération de vitesses suivant une distribution normale
        vitesses_gaussiennes = torch.normal(mean=self.velocity_magnitude, std=self.ecart_type, size=(self.num_cells,), device=device)

        # Logique pour placer les cellules en respectant la distance minimale
        if self.min_distance != 0:
            grid_size = int(np.ceil(self.space_size / self.min_distance))
            grid = [[[] for _ in range(grid_size)] for _ in range(grid_size)]
            
            for i, position in enumerate(positions):
                # Essayer de placer la cellule sans conflits
                placed = False
                while not placed:
                    grid_x = int(position[0] / self.min_distance)
                    grid_y = int(position[1] / self.min_distance)
                    # Vérification des conflits avec les cellules voisines
                    conflicts = any(torch.norm(position - other_position) < self.min_distance for other_position in grid[grid_x][grid_y])
                    if not conflicts:
                        for dx in [-1, 0, 1]:
                            for dy in [-1, 0, 1]:
                                if dx == 0 and dy == 0:
                                    continue
                                nx, ny = grid_x + dx, grid_y + dy
                                if 0 <= nx < grid_size and 0 <= ny < grid_size:
                                    conflicts = any(torch.norm(position - other_position) < self.min_distance for other_position in grid[nx][ny])
                                    if conflicts:
                                        break
                            if conflicts:
                                break
                    if not conflicts:
                        # Placement réussi sans conflit
                        grid[grid_x][grid_y].append(position)
                        velocity = directions[i] * vitesses_gaussiennes[i]
                        self.cells.append(CellAgent(cell_id_counter, self.pop_tag, position, velocity,
                                                    vitesses_gaussiennes[i], self.persistence, self.space_size,
                                                    self.tau, self.noise, self.cell_params, self.sensitivity_cAMP_threshold))
                        cell_id_counter += 1
                        placed = True
                    else:
                        # Générer une nouvelle position aléatoire
                        position = torch.rand(2, device=device) * self.space_size
        else:
            # Si la distance minimale est zéro, on place les cellules sans contrainte
            for i, position in enumerate(positions):
                velocity = directions[i] * vitesses_gaussiennes[i]
                self.cells.append(CellAgent(cell_id_counter, self.pop_tag, position, velocity,
                                            vitesses_gaussiennes[i], self.persistence, self.space_size,
                                            self.tau, self.noise, self.cell_params, self.sensitivity_cAMP_threshold))
                cell_id_counter += 1

class Surface:
    def get_friction(self, position):
        """
        Retourne la friction de la surface à une position donnée.
        Ici, elle est générée aléatoirement entre 0 et 0.2.

        Paramètres:
        - position: Position pour laquelle on veut la friction (non utilisée)

        Retourne:
        - friction: Valeur de friction à la position donnée
        """
        friction = torch.empty(1).uniform_(0, 0.2).to(device)
        return friction.item()
        
class cAMP:
    def __init__(self, space_size, cell_params, initial_condition=None):
        """
        Classe représentant le champ de concentration du cAMP dans l'espace.

        Résout l'équation de diffusion-dégradation-production du cAMP :
            ∂S/∂t = D_cAMP ∇²S - aPDE * S + P(x, y, t)

        Le terme de production est défini par :
            P(x, y, t) = Σ_cells [ a0 + D_cell * H(A_cell - af) * δ(x - x_cell, y - y_cell) ]
                
        Où :
        - S(x, y, t) : Concentration de cAMP à la position (x, y) et au temps t.
        - D_cAMP : Coefficient de diffusion du cAMP.
        - ∇²S : Laplacien de S, représentant la diffusion spatiale.
        - aPDE : Taux de dégradation du cAMP.
        - P(x, y, t) : Terme de production de cAMP par les cellules activées.
        - a0 : Taux de production basal de cAMP.
        - D_cell : Taux de production de cAMP par une cellule activée.

        Paramètres:
        - space_size: Taille de l'espace de simulation.
        - cell_params: Dictionnaire des paramètres du modèle de FitzHugh-Nagumo
        - initial_condition: Condition initiale de la concentration de cAMP (optionnelle).
        """
        self.space_size = space_size
        self.grid_resolution = cell_params['grid_resolution']
        self.grid_size = int(space_size / self.grid_resolution)
        self.D_cAMP = cell_params['D_cAMP']  # Coefficient de diffusion
        self.aPDE = cell_params['aPDE']      # Taux de dégradation
        self.a0 = cell_params['a0']          # Production basale de cAMP
        self.dx = self.grid_resolution       # Pas spatial
        self.dt = DELTA_T                     # Pas de temps de la simulation

        # Création de la grille de coordonnées
        x = torch.linspace(0, space_size, self.grid_size, device=device)
        y = torch.linspace(0, space_size, self.grid_size, device=device)
        self.X, self.Y = torch.meshgrid(x, y, indexing='ij')

        # Initialisation de la grille de concentration du cAMP
        if initial_condition is None:
            # Par défaut, concentration nulle partout
            self.signal = torch.zeros((self.grid_size, self.grid_size), device=device)
        else:
            # Si une fonction ou un tableau est fourni pour l'état initial
            if callable(initial_condition):
                # Utiliser la fonction pour définir la concentration initiale
                self.signal = initial_condition(self.X, self.Y)
            elif isinstance(initial_condition, torch.Tensor):
                # Vérifier que la taille correspond
                if initial_condition.shape == (self.grid_size, self.grid_size):
                    self.signal = initial_condition.to(device)
                else:
                    raise ValueError("La forme de initial_condition ne correspond pas à la grille.")
            else:
                # Supposer que c'est une valeur scalaire
                self.signal = torch.full((self.grid_size, self.grid_size), initial_condition, device=device)

    def compute_laplacian(self, S):
        """
        Calcule le Laplacien du signal S avec des conditions aux limites périodiques.

        Paramètres:
        - S: Grille de concentration du cAMP

        Retourne:
        - laplacian_S: Grille du Laplacien de S
        """
        # Utilisation de torch.roll pour implémenter les conditions périodiques
        laplacian_S = (
            torch.roll(S, shifts=1, dims=0) + torch.roll(S, shifts=-1, dims=0) +
            torch.roll(S, shifts=1, dims=1) + torch.roll(S, shifts=-1, dims=1) -
            4 * S
        ) / self.dx ** 2
        return laplacian_S

    def update(self, cells):
        """
        Met à jour la concentration du cAMP en fonction de la production par les cellules,
        de la diffusion et de la dégradation.

        Paramètres:
        - cells: Liste des cellules dans la simulation (peut être vide).
        """
        # Initialisation du terme de production à zéro
        A_grid = torch.zeros_like(self.signal)

        if len(cells) > 0:  # Si des cellules sont présentes
            for cell in cells:
                x_idx = int(cell.position[0].item() / self.grid_resolution) % self.grid_size
                y_idx = int(cell.position[1].item() / self.grid_resolution) % self.grid_size
                # Production basale de cAMP
                A_grid[x_idx, y_idx] += cell.a0
                # Production supplémentaire si la cellule est activée
                if cell.A > cell.af:
                    A_grid[x_idx, y_idx] += cell.D  # D est le taux de production de cAMP par les cellules activées

        # Diffusion et dégradation du cAMP
        laplacian_S = self.compute_laplacian(self.signal)

        # Appliquer la dégradation (uniquement si des cellules sont présentes)
        degradation_term = self.aPDE * self.signal if len(cells) > 0 else 0.0

        # Mise à jour du signal : diffusion, dégradation, et production
        self.signal += self.dt * (self.D_cAMP * laplacian_S - degradation_term + A_grid)
        self.signal = torch.clamp(self.signal, min=0)  # Pour éviter les valeurs négatives

        # Vérification des NaN dans le signal
        if torch.isnan(self.signal).any() or torch.isinf(self.signal).any():
            print(f"NaN or Inf detected in cAMP signal at iteration corresponding to time {self.dt * iteration:.2f} min")
            sys.exit(1)

    def get_signal_at_position(self, position):
        """
        Renvoie la concentration du cAMP à une position donnée, avec conditions périodiques.

        Paramètres:
        - position: Position pour laquelle on veut connaître la concentration de cAMP

        Retourne:
        - Concentration de cAMP à la position donnée
        """
        x_idx = int(position[0].item() / self.grid_resolution) % self.grid_size
        y_idx = int(position[1].item() / self.grid_resolution) % self.grid_size
        return self.signal[x_idx, y_idx]

# Paramètres de contrôle
INCLUDE_CELLS = True # Mettre à False pour exclure les cellules de la simulation
INITIAL_AMPc = False # True si présence d'AMPc initiale
PLOT = True

# In[Simulation parameters]
R_SENSING_GRAD = 4.0  # Distance en μm sur laquelle la cellule peut sentir le gradient

# Paramètres des cellules pour le modèle de FitzHugh-Nagumo
cell_params = {
    'c0': 1.0,        # Terme constant dans l'équation de R
    'a': 5.0,         # Couplage entre le signal et l'activateur A
    'gamma': 0.1,     # Taux de relaxation du répresseur R
    'Kd': 0.5,        # Ajuster Kd pour définir la sensibilité au cAMP
    'sigma': 0.05,    # Intensité du bruit pour A
    'epsilon': 0.2,   # Ajuster le taux de relaxation de R
    'D': 150.0,         # Taux de production de cAMP par les cellules activées (réduit)
    'a0': 0.0,        # Production basale de cAMP
    'af': 0.1,        # Seuil d'activation pour la production de cAMP
    'noise': True,
    'D_cAMP': 2400.0,   # Coefficient de diffusion du cAMP μm2/min (40 μm2/s)
    'aPDE': 1.0,      # Taux de dégradation du cAMP
    'grid_resolution': 0.5,  # Taille des cellules de la grille (μm)
    'chemotaxis_sensitivity' : 0.5 # Paramètre de chimiotaxie (sensibilité au gradient de cAMP)
    #C'est le % de suivi de la direction en cours, avec alignment avec le grad cAMP alentours. 
}

# Paramètres de l'espace
SPACE_SIZE = 50  # Taille de l'espace de simulation en micromètres
# Paramètres temporels
TIME_SIMU = 1000  # Temps total de simulation en minutes
# DELTA_T = 0.001 
DELTA_T =  (cell_params['grid_resolution']**2)/(4*cell_params['D_cAMP'])  # Pas de temps de la simulation en minutes (réduit pour stabilité)
#D'après le critère de stabilité de Couran_Friedrichs_Lewy (CFL) delta_T <= ((Δx)**2)/(4*D_cAMP)) 
PLOT_INTERVAL = int(1/DELTA_T)  # Intervalle pour la sauvegarde des images

# Définition des populations
if INCLUDE_CELLS: # Si on décide d'avoir des cellules (paramètre de contrôle)
    MU = 1  # Mobilité (μm / min·kg⁻¹)
    F_REP = 40  # Intensité de la force de répulsion
    F_ADH = 7  # Intensité de la force d'adhésion
    R_EQ = 1.1  # Rayon d'équilibre (μm)
    R_0 = 1.6  # Rayon maximal d'interaction (μm)
    MIN_DISTANCE_INIT = R_EQ  # Distance minimale entre cellules à l'initialisation
    COEFF_CARRE = 50  # Coefficient quadratique (non utilisé ici)
    COEFF_REP = 0.5  # Coefficient pour ajuster la force de répulsion
    # Trace la fonction de force pour visualiser les forces de répulsion et d'adhésion
    plot_function(pas=0.01, Req=R_EQ, R0=R_0, Frep=F_REP,
                Fadh=F_ADH, a=COEFF_CARRE, coeff_rep=COEFF_REP)

    # Facteur de fluctuation pour la vitesse
    FLUCTUATION_FACTOR = 3

    # Définition des cellules
    PACKING_FRACTION = 0.004  # Fraction de l'espace occupée par les cellules
    # Calcul du nombre de cellules en fonction de la fraction de remplissage
    N_CELLS = int((PACKING_FRACTION * SPACE_SIZE ** 2) /
                (math.pi * ((R_EQ / 2) ** 2)))  # Nombre total de cellules
    print(N_CELLS, "cells")
    # Paramètres de la Population 1
    velocity_magnitude_pop1 = 0 * 3  # Vitesse moyenne des cellules de la population 1 (μm/min)
    ECART_TYPE_POP1 = 0.3  # Écart-type de la vitesse pour la population 1
    NOISE_POP_1 = 0 * 8  # Intensité du bruit pour la population 1
    TAU_POP_1 = 5  # Temps caractéristique pour la population 1
    PERSISTENCE_POP1 = 0  # Persistance du mouvement pour la population 1
    SENSITIVITY_cAMP_THRESHOLD_POP1 = 0.1

    # Paramètres de la Population 2
    velocity_magnitude_pop2 = 0 * 8  # Vitesse moyenne des cellules de la population 2 (μm/min)
    ECART_TYPE_POP2 = 0.5  # Écart-type de la vitesse pour la population 2
    NOISE_POP_2 = 0 * 5  # Intensité du bruit pour la population 2
    TAU_POP_2 = 5  # Temps caractéristique pour la population 2
    PERSISTENCE_POP2 = 0  # Persistance du mouvement pour la population 2
    SENSITIVITY_cAMP_THRESHOLD_POP2 = 0.1

    cell_id_counter = 0  # Initialisation du compteur d'ID des cellules
    population1 = Population(num_cells=int(N_CELLS / 2), space_size=SPACE_SIZE,
                            velocity_magnitude=velocity_magnitude_pop1,
                            persistence=PERSISTENCE_POP1, ecart_type=ECART_TYPE_POP1,
                            min_distance=MIN_DISTANCE_INIT, pop_tag="Population 1",
                            tau=TAU_POP_1, noise=NOISE_POP_1, cell_params=cell_params,
                            sensitivity_cAMP_threshold=SENSITIVITY_cAMP_THRESHOLD_POP1)

    population2 = Population(num_cells=int(N_CELLS / 2), space_size=SPACE_SIZE,
                            velocity_magnitude=velocity_magnitude_pop2,
                            persistence=PERSISTENCE_POP2, ecart_type=ECART_TYPE_POP2,
                            min_distance=MIN_DISTANCE_INIT, pop_tag="Population 2",
                            tau=TAU_POP_2, noise=NOISE_POP_2, cell_params=cell_params,
                            sensitivity_cAMP_threshold=SENSITIVITY_cAMP_THRESHOLD_POP2)

    # Combinaison des cellules des deux populations
    cells = population1.cells + population2.cells

    # Initialisations des positions et vitesses des cellules.
    positions = torch.stack([cell.position_init for cell in cells])
    V0 = torch.tensor([cell.velocity_magnitude for cell in cells], device=device).unsqueeze(1)
    direction = torch.stack([cell.direction for cell in cells])
    positions = torch.stack([cell.position for cell in cells])
    
else:
    cells = []  # Liste vide si on n'inclut pas les cellules

surface = Surface()  # Création d'une instance de Surface (non utilisée ici)

# In[Initialisation du système]
##### no gradient condition initial #######
def no_gradient_initial_condition(X, Y):
    return torch.full_like(X, 0.5, device=device)

##### Fonction pour créer un gradient de concentration de 0 en haut à 100 en bas ##### 
def gradient_haut_bas_initial_condition(X, Y):
    return (Y / SPACE_SIZE) * 100.0  # Y varie de 0 à SPACE_SIZE

##### Gradient linéaire max au centre min en hau et bas #######
def gradient_max_centre_min_haut_bas_initial_condition(X, Y):
    max_concentration = 25.0  # Valeur maximale de la concentration au milieu
    return (max_concentration * (1 - ((2 * (Y - SPACE_SIZE / 2) / SPACE_SIZE) ** 2))).to(device)

##### Gradient linéaire radial partant du centre #######
def gradient_radial_initial_condition(X, Y):
    X_c = SPACE_SIZE / 2
    Y_c = SPACE_SIZE / 2
    R_max = math.sqrt(2) * (SPACE_SIZE / 2)  # Distance maximale au coin de l'espace
    R = torch.sqrt((X - X_c) ** 2 + (Y - Y_c) ** 2)
    max_concentration = 10.0
    signal = max_concentration * (1 - R / R_max)
    signal = torch.clamp(signal, min=0.0)  # Éviter les valeurs négatives
    return signal.to(device)

##### Tâche circulaire au centre de l'espace #######
def gradient_initial_condition(X, Y, center_value=10000.0, radius=50.0):
    """
    Crée une tache circulaire de cAMP au centre de la grille avec une concentration maximale au centre 
    et nulle en dehors d'un certain rayon.

    Paramètres:
    - X, Y: Les grilles de coordonnées en 2D.
    - center_value: Valeur maximale de la concentration de cAMP au centre de la tache.
    - radius: Rayon de la tache de cAMP (en unités de distance de la grille).

    Retourne:
    - signal: Grille de concentration de cAMP avec une tache circulaire au centre.
    """
    # Centre de la grille
    X_c = X.mean().item()
    Y_c = Y.mean().item()

    # Calcul de la distance de chaque point au centre
    distance_from_center = torch.sqrt((X - X_c) ** 2 + (Y - Y_c) ** 2)
    
    # Créer un masque où la distance est inférieure au rayon de la tache
    mask = distance_from_center <= radius

    # Initialiser le signal à zéro
    signal = torch.zeros_like(X)

    # Appliquer la valeur de cAMP dans la région de la tache
    signal[mask] = center_value

    return signal

if INITIAL_AMPc is True:
    # Initialisation de la grille de cAMP avec le gradient initial
    camp_field = cAMP(SPACE_SIZE, cell_params,
                    initial_condition=gradient_initial_condition)
    plot_camp_field(camp_field, space_size=SPACE_SIZE, iteration=0)
else:
    camp_field = cAMP(SPACE_SIZE, cell_params,
                    initial_condition=None)

# Plot du l'état initial
if PLOT:
    # Définition du chemin pour sauvegarder les images
    PATH = f'../simulations_images/v1{velocity_magnitude_pop1}v2{velocity_magnitude_pop2}a{COEFF_CARRE}coefrep{COEFF_REP}fadh{F_ADH}frep{F_REP}/'
    if not os.path.exists(PATH):
        os.makedirs(PATH)
    else:
        print("WARNING : FOLDER DOES ALREADY EXIST!")
        sys.exit(0)
    
    # Création d'une figure et d'un axe pour le tracé initial
    fig, ax = plt.subplots(figsize=(6, 6))
    plot_environment(cells, camp_field, SPACE_SIZE, axis=ax, iteration=0)
    
    # Sauvegarde de l'image initiale
    plt.savefig(f'{PATH}image_0.png', bbox_inches='tight', dpi=300, pad_inches=0)
    plt.close()

# In[Simulation]
time = 0  # Initialisation du temps
iteration = 1  # Compteur d'itérations
MAX_DISTANCE = np.sqrt(2 * (SPACE_SIZE / 2) ** 2)  # Distance maximale possible dans l'espace
# Création d'une liste pour stocker les données de simulation
data_list = []
while time < TIME_SIMU:
    if INCLUDE_CELLS:
        # Mise à jour des états A et R des cellules
        for cell in cells:
            signal_value = camp_field.get_signal_at_position(cell.position)
            cell.update_state(signal_value, DELTA_T)
            # if cell.A > cell.af:
            #     print(f"Cell {cell.id} is producing cAMP at time {time:.2f} with A = {cell.A.item():.2f}")

    # Mise à jour de la grille de cAMP
    camp_field.update(cells)
    # Impression seul de la map d'AMPc si condition initiale (pas nécessaire?)
    if INITIAL_AMPc is True:
        if iteration % PLOT_INTERVAL == 0:
            plot_camp_field(camp_field, space_size=SPACE_SIZE, iteration=time)

    # Vérification des NaN dans le signal de cAMP
    if torch.isnan(camp_field.signal).any() or torch.isinf(camp_field.signal).any():
        print(f"NaN or Inf detected in cAMP signal at iteration {iteration}")
        sys.exit(1)

    if INCLUDE_CELLS:
        # Calcul du gradient du cAMP pour chaque cellule et ajustement de la direction
        for cell in cells:
            # Obtenir la concentration de cAMP à la position de la cellule
            local_camp_concentration = camp_field.get_signal_at_position(cell.position)
            # Vérifier si la concentration est supérieure au seuil de sensibilité de la cellule
            if local_camp_concentration >= cell.sensitivity_threshold:
                # La cellule suit le gradient
                grad_cAMP = compute_local_gradient(camp_field.signal, cell.position, camp_field.grid_resolution, r_sensing=R_SENSING_GRAD)
                if torch.norm(grad_cAMP) > 0:
                    grad_cAMP = grad_cAMP / torch.norm(grad_cAMP)  # Normalisation du gradient
                    # Mise à jour de la direction de la cellule en tenant compte de la chimiotaxie
                    cell.direction = (1 - cell_params['chemotaxis_sensitivity']) * cell.direction + \
                        cell_params['chemotaxis_sensitivity'] * grad_cAMP
                    cell.direction = torch.nn.functional.normalize(cell.direction, p=2, dim=0)
            else:
                # La cellule ne suit pas le gradient
                pass  # Par exemple, ne rien changer à la direction

        # Calcul des différences de coordonnées entre les cellules (pour les forces)
        positions = torch.stack([cell.position for cell in cells])
        coordinates_diff = ((positions[:, None, :] - positions[None, :, :]))
        # Gestion des conditions périodiques aux limites (torus)
        coordinates_diff = torch.remainder(coordinates_diff - (SPACE_SIZE / 2), SPACE_SIZE) - (SPACE_SIZE / 2)
        distances = torch.stack([torch.norm(coordinates_diff[i], dim=1) for i in range(len(coordinates_diff))])
        is_greater_than_max = torch.any(distances > MAX_DISTANCE)

        if is_greater_than_max:
            print("At least one distance is greater than the max distance.")

        # Calcul du champ de forces entre les cellules
        force_field = force_field_inbox(coordinates_diff, distances, Req=R_EQ,
                                        R0=R_0, Frep=F_REP, Fadh=F_ADH,
                                        coeff_a=COEFF_CARRE, coeff_rep=COEFF_REP)
        
        # Vérification des NaN dans le force_field
        if torch.isnan(force_field).any() or torch.isinf(force_field).any():
            print(f"NaN or Inf detected in force_field at iteration {iteration}")
            sys.exit(1)
    
        # Calcul du déplacement des cellules
        V0 = torch.tensor([cell.velocity_magnitude for cell in cells], device=device).unsqueeze(1)
        direction = torch.stack([cell.direction for cell in cells])
        # Ajout de fluctuations aléatoires à la vitesse
        fluctuations = (torch.rand(V0.shape, device=device) - 0.5) * FLUCTUATION_FACTOR
        # Calcul du déplacement total : contribution du mouvement propre et des forces intercellulaires
        displacement = MU * force_field * DELTA_T + (V0 + fluctuations) * direction * DELTA_T
        
        # Vérification des NaN dans le déplacement
        if torch.isnan(displacement).any() or torch.isinf(displacement).any():
            print(f"NaN or Inf detected in displacement at iteration {iteration}")
            sys.exit(1)
        
        positions += displacement

        # Mise à jour des positions des cellules
        for idx, cell in enumerate(cells):
            cell.position += displacement[idx]
            cell.position = torch.remainder(cell.position, SPACE_SIZE)  # Conditions périodiques aux limites

            # Vérification des NaN dans la position
            if torch.isnan(cell.position).any() or torch.isinf(cell.position).any():
                print(f"NaN or Inf detected in position of cell {cell.id} at iteration {iteration}")
                sys.exit(1)

            # Mise à jour de la direction de la cellule
            new_direction = autovel(displacement[idx].unsqueeze(0), cell.direction.unsqueeze(0),
                                    cell.tau, cell.noise, DELTA_T, persistence=cell.persistence)
            cell.direction = new_direction.squeeze(0)

            # Vérification des NaN dans la direction
            if torch.isnan(cell.direction).any() or torch.isinf(cell.direction).any():
                print(f"NaN or Inf detected in direction of cell {cell.id} at iteration {iteration}")
                sys.exit(1)
            if iteration % PLOT_INTERVAL == 0:
                # Enregistrement des informations de la cellule pour l'analyse
                data_list.append({
                    'frame': time,
                    'particle': cell.id,
                    'pop_tag': cell.pop,
                    'x': cell.position[0].item(),
                    'y': cell.position[1].item(),
                    'dir_x': cell.direction[0].item(),
                    'dir_y': cell.direction[1].item()
                })
    
    # Modification du bloc PLOT
    if PLOT:
        if iteration % PLOT_INTERVAL == 0:
            print(f"on est dans le plot time {time}")
            marker_radius = 1.1
            marker_size = (np.pi) * marker_radius ** 2
            # Créer une figure avec 4 sous-graphes en ligne
            fig, axes = plt.subplots(1, 4, figsize=(24, 6))

            # Graphique 1 : Environnement de simulation
            plot_environment(cells, camp_field, SPACE_SIZE, axis=axes[0], iteration=iteration)

            # Graphique 2 : Champ de cAMP
            extent = [0, SPACE_SIZE, 0, SPACE_SIZE]
            im1 = axes[1].imshow(camp_field.signal.cpu().numpy().T, origin='lower', extent=extent, cmap='viridis', alpha=0.8)
            axes[1].set_title(f'Champ de cAMP à l\'itération {iteration}')
            axes[1].set_xlabel('Position X (μm)')
            axes[1].set_ylabel('Position Y (μm)')
            fig.colorbar(im1, ax=axes[1], label='Concentration de cAMP')

            # Création des grilles pour A et R avec conditions périodiques
            grid_size = camp_field.grid_size
            A_grid = torch.zeros((grid_size, grid_size), device=device)
            R_grid = torch.zeros((grid_size, grid_size), device=device)
            cell_counts = torch.zeros((grid_size, grid_size), device=device)

            for cell in cells:
                x_idx = int(cell.position[0].item() / camp_field.grid_resolution) % grid_size
                y_idx = int(cell.position[1].item() / camp_field.grid_resolution) % grid_size
                A_grid[x_idx, y_idx] += cell.A
                R_grid[x_idx, y_idx] += cell.R
                cell_counts[x_idx, y_idx] += 1

            # Éviter la division par zéro
            cell_counts_nonzero = cell_counts.clone()
            cell_counts_nonzero[cell_counts_nonzero == 0] = 1

            A_grid_avg = A_grid / cell_counts_nonzero
            R_grid_avg = R_grid / cell_counts_nonzero

            # Graphique 3 : Concentration de A
            im2 = axes[2].imshow(A_grid_avg.cpu().numpy().T, origin='lower', extent=extent, cmap='GnBu', alpha=0.8)
            axes[2].set_title(f'Concentration de A à l\'itération {iteration}')
            axes[2].set_xlabel('Position X (μm)')
            axes[2].set_ylabel('Position Y (μm)')
            fig.colorbar(im2, ax=axes[2], label='Concentration de A')

            # Graphique 4 : Concentration de R
            im3 = axes[3].imshow(R_grid_avg.cpu().numpy().T, origin='lower', extent=extent, cmap='BuGn', alpha=0.8)
            axes[3].set_title(f'Concentration de R à l\'itération {iteration}')
            axes[3].set_xlabel('Position X (μm)')
            axes[3].set_ylabel('Position Y (μm)')
            fig.colorbar(im3, ax=axes[3], label='Concentration de R')

            # Sauvegarder la figure
            plt.tight_layout()
            plt.savefig(f'{PATH}combined_{iteration}.png', bbox_inches='tight', dpi=300, pad_inches=0)
            plt.close()

    # Mise à jour du temps et de l'itération
    time += DELTA_T
    iteration += 1
# Out:
# Device for torch operations: cpu
# 10 cells
# on est dans le plot time 0
# on est dans le plot time 2.604166666666667e-05
# on est dans le plot time 5.208333333333334e-05
# on est dans le plot time 7.8125e-05
# on est dans le plot time 0.00010416666666666667
# on est dans le plot time 0.00013020833333333333
# on est dans le plot time 0.00015625
# on est dans le plot time 0.00018229166666666667
# on est dans le plot time 0.00020833333333333335
# on est dans le plot time 0.00023437500000000002
# on est dans le plot time 0.00026041666666666666
# on est dans le plot time 0.00028645833333333333
# on est dans le plot time 0.0003125
# on est dans le plot time 0.0003385416666666667
# on est dans le plot time 0.00036458333333333335
# on est dans le plot time 0.000390625
# on est dans le plot time 0.0004166666666666667
# on est dans le plot time 0.00044270833333333337
# on est dans le plot time 0.00046875000000000004
# on est dans le plot time 0.0004947916666666667
# on est dans le plot time 0.0005208333333333333
# on est dans le plot time 0.0005468749999999999
# on est dans le plot time 0.0005729166666666666
# on est dans le plot time 0.0005989583333333332
# on est dans le plot time 0.0006249999999999998
# on est dans le plot time 0.0006510416666666664
# on est dans le plot time 0.000677083333333333
# on est dans le plot time 0.0007031249999999996
# on est dans le plot time 0.0007291666666666663
# on est dans le plot time 0.0007552083333333329
# on est dans le plot time 0.0007812499999999995
# on est dans le plot time 0.0008072916666666661
# on est dans le plot time 0.0008333333333333327
# on est dans le plot time 0.0008593749999999994
# on est dans le plot time 0.000885416666666666
# on est dans le plot time 0.0009114583333333326
# on est dans le plot time 0.0009374999999999992
# on est dans le plot time 0.0009635416666666658
# on est dans le plot time 0.0009895833333333325
# on est dans le plot time 0.0010156249999999992
# on est dans le plot time 0.0010416666666666658
# on est dans le plot time 0.0010677083333333324
# on est dans le plot time 0.001093749999999999
# on est dans le plot time 0.0011197916666666656
# on est dans le plot time 0.0011458333333333323
# on est dans le plot time 0.0011718749999999989
# on est dans le plot time 0.0011979166666666655
# on est dans le plot time 0.001223958333333332
# on est dans le plot time 0.0012499999999999987
# on est dans le plot time 0.0012760416666666653
# on est dans le plot time 0.001302083333333332
# on est dans le plot time 0.0013281249999999986
# on est dans le plot time 0.0013541666666666652
# on est dans le plot time 0.0013802083333333318
# on est dans le plot time 0.0014062499999999984
# on est dans le plot time 0.001432291666666665
# on est dans le plot time 0.0014583333333333317
# on est dans le plot time 0.0014843749999999983
# on est dans le plot time 0.001510416666666665
# on est dans le plot time 0.0015364583333333315
# on est dans le plot time 0.0015624999999999981
# on est dans le plot time 0.0015885416666666648
# on est dans le plot time 0.0016145833333333314
# on est dans le plot time 0.001640624999999998
# on est dans le plot time 0.0016666666666666646
# on est dans le plot time 0.0016927083333333312
# on est dans le plot time 0.0017187499999999978
# on est dans le plot time 0.0017447916666666645
# on est dans le plot time 0.001770833333333331
# on est dans le plot time 0.0017968749999999977
# on est dans le plot time 0.0018229166666666643
# on est dans le plot time 0.001848958333333331
# on est dans le plot time 0.0018749999999999975
# on est dans le plot time 0.0019010416666666642
# on est dans le plot time 0.0019270833333333308
# on est dans le plot time 0.0019531249999999974
# on est dans le plot time 0.0019791666666666642
# on est dans le plot time 0.002005208333333331
# on est dans le plot time 0.002031249999999998
# on est dans le plot time 0.0020572916666666647
# on est dans le plot time 0.0020833333333333316
# on est dans le plot time 0.0021093749999999984
# on est dans le plot time 0.0021354166666666652
# on est dans le plot time 0.002161458333333332
# on est dans le plot time 0.002187499999999999
# on est dans le plot time 0.0022135416666666657
# on est dans le plot time 0.0022395833333333326
# on est dans le plot time 0.0022656249999999994
# on est dans le plot time 0.0022916666666666662
# on est dans le plot time 0.002317708333333333
# on est dans le plot time 0.00234375
# on est dans le plot time 0.0023697916666666667
# on est dans le plot time 0.0023958333333333336
# on est dans le plot time 0.0024218750000000004
# on est dans le plot time 0.0024479166666666673
# on est dans le plot time 0.002473958333333334
# on est dans le plot time 0.002500000000000001
# on est dans le plot time 0.0025260416666666678
# on est dans le plot time 0.0025520833333333346
# on est dans le plot time 0.0025781250000000014
# on est dans le plot time 0.0026041666666666683
# on est dans le plot time 0.002630208333333335
# on est dans le plot time 0.002656250000000002
# on est dans le plot time 0.0026822916666666688
# on est dans le plot time 0.0027083333333333356
# on est dans le plot time 0.0027343750000000024
# on est dans le plot time 0.0027604166666666693
# on est dans le plot time 0.002786458333333336
# on est dans le plot time 0.002812500000000003
# on est dans le plot time 0.0028385416666666698
# on est dans le plot time 0.0028645833333333366
# on est dans le plot time 0.0028906250000000034
# on est dans le plot time 0.0029166666666666703
# on est dans le plot time 0.002942708333333337
# on est dans le plot time 0.002968750000000004
# on est dans le plot time 0.0029947916666666708
# on est dans le plot time 0.0030208333333333376
# on est dans le plot time 0.0030468750000000044
# on est dans le plot time 0.0030729166666666713
# on est dans le plot time 0.003098958333333338
# on est dans le plot time 0.003125000000000005
# on est dans le plot time 0.0031510416666666718
# on est dans le plot time 0.0031770833333333386
# on est dans le plot time 0.0032031250000000054
# on est dans le plot time 0.0032291666666666723
# on est dans le plot time 0.003255208333333339
# on est dans le plot time 0.003281250000000006
# on est dans le plot time 0.003307291666666673
# on est dans le plot time 0.0033333333333333396
# on est dans le plot time 0.0033593750000000065
# on est dans le plot time 0.0033854166666666733
# on est dans le plot time 0.00341145833333334
# on est dans le plot time 0.003437500000000007
# on est dans le plot time 0.003463541666666674
# on est dans le plot time 0.0034895833333333406
# on est dans le plot time 0.0035156250000000075
# on est dans le plot time 0.0035416666666666743
# on est dans le plot time 0.003567708333333341
# on est dans le plot time 0.003593750000000008
# on est dans le plot time 0.003619791666666675
# on est dans le plot time 0.0036458333333333416
# on est dans le plot time 0.0036718750000000085
# on est dans le plot time 0.0036979166666666753
# on est dans le plot time 0.003723958333333342
# on est dans le plot time 0.003750000000000009
# on est dans le plot time 0.003776041666666676
# on est dans le plot time 0.0038020833333333426
# on est dans le plot time 0.0038281250000000095
# on est dans le plot time 0.0038541666666666763
# on est dans le plot time 0.003880208333333343
# on est dans le plot time 0.0039062500000000095
# on est dans le plot time 0.003932291666666676
# on est dans le plot time 0.003958333333333342
# on est dans le plot time 0.003984375000000009
# on est dans le plot time 0.004010416666666675
# on est dans le plot time 0.0040364583333333415
# on est dans le plot time 0.004062500000000008
# on est dans le plot time 0.004088541666666674
# on est dans le plot time 0.004114583333333341
# on est dans le plot time 0.004140625000000007
# on est dans le plot time 0.0041666666666666735
# on est dans le plot time 0.00419270833333334
# on est dans le plot time 0.004218750000000006
# on est dans le plot time 0.004244791666666673
# on est dans le plot time 0.004270833333333339
# on est dans le plot time 0.0042968750000000056
# on est dans le plot time 0.004322916666666672
# on est dans le plot time 0.004348958333333338
# on est dans le plot time 0.004375000000000005
# on est dans le plot time 0.004401041666666671
# on est dans le plot time 0.0044270833333333376
# on est dans le plot time 0.004453125000000004
# on est dans le plot time 0.00447916666666667
# on est dans le plot time 0.004505208333333337
# on est dans le plot time 0.004531250000000003
# on est dans le plot time 0.0045572916666666696
# on est dans le plot time 0.004583333333333336
# on est dans le plot time 0.004609375000000002
# on est dans le plot time 0.004635416666666669
# on est dans le plot time 0.004661458333333335
# on est dans le plot time 0.0046875000000000016
# on est dans le plot time 0.004713541666666668
# on est dans le plot time 0.004739583333333334
# on est dans le plot time 0.004765625000000001
# on est dans le plot time 0.004791666666666667
# on est dans le plot time 0.0048177083333333336
# on est dans le plot time 0.00484375
# on est dans le plot time 0.004869791666666666
# on est dans le plot time 0.004895833333333333
# on est dans le plot time 0.004921874999999999
# on est dans le plot time 0.004947916666666666
# on est dans le plot time 0.004973958333333332
# on est dans le plot time 0.004999999999999998
# on est dans le plot time 0.005026041666666665
# on est dans le plot time 0.005052083333333331
# on est dans le plot time 0.005078124999999998
# on est dans le plot time 0.005104166666666664
# on est dans le plot time 0.00513020833333333
# on est dans le plot time 0.005156249999999997
# on est dans le plot time 0.005182291666666663
# on est dans le plot time 0.00520833333333333
# on est dans le plot time 0.005234374999999996
# on est dans le plot time 0.005260416666666662
# on est dans le plot time 0.005286458333333329
# on est dans le plot time 0.005312499999999995
# on est dans le plot time 0.005338541666666662
# on est dans le plot time 0.005364583333333328
# on est dans le plot time 0.005390624999999994
# on est dans le plot time 0.005416666666666661
# on est dans le plot time 0.005442708333333327
# on est dans le plot time 0.005468749999999994
# on est dans le plot time 0.00549479166666666
# on est dans le plot time 0.005520833333333326
# on est dans le plot time 0.005546874999999993
# on est dans le plot time 0.005572916666666659
# on est dans le plot time 0.005598958333333326
# on est dans le plot time 0.005624999999999992
# on est dans le plot time 0.005651041666666658
# on est dans le plot time 0.005677083333333325
# on est dans le plot time 0.005703124999999991
# on est dans le plot time 0.005729166666666658
# on est dans le plot time 0.005755208333333324
# on est dans le plot time 0.00578124999999999
# on est dans le plot time 0.005807291666666657
# on est dans le plot time 0.005833333333333323
# on est dans le plot time 0.00585937499999999
# on est dans le plot time 0.005885416666666656
# on est dans le plot time 0.005911458333333322
# on est dans le plot time 0.005937499999999989
# on est dans le plot time 0.005963541666666655
# on est dans le plot time 0.005989583333333322
# on est dans le plot time 0.006015624999999988
# on est dans le plot time 0.006041666666666654
# on est dans le plot time 0.006067708333333321
# on est dans le plot time 0.006093749999999987
# on est dans le plot time 0.006119791666666654
# on est dans le plot time 0.00614583333333332
# on est dans le plot time 0.006171874999999986
# on est dans le plot time 0.006197916666666653
# on est dans le plot time 0.006223958333333319
# on est dans le plot time 0.006249999999999986
# on est dans le plot time 0.006276041666666652
# on est dans le plot time 0.006302083333333318
# on est dans le plot time 0.006328124999999985
# on est dans le plot time 0.006354166666666651
# on est dans le plot time 0.006380208333333318
# on est dans le plot time 0.006406249999999984
# on est dans le plot time 0.00643229166666665
# on est dans le plot time 0.006458333333333317
# on est dans le plot time 0.006484374999999983
# on est dans le plot time 0.00651041666666665
# on est dans le plot time 0.006536458333333316
# on est dans le plot time 0.006562499999999982
# on est dans le plot time 0.006588541666666649
# on est dans le plot time 0.006614583333333315
# on est dans le plot time 0.006640624999999982
# on est dans le plot time 0.006666666666666648
# on est dans le plot time 0.006692708333333314
# on est dans le plot time 0.006718749999999981
# on est dans le plot time 0.006744791666666647
# on est dans le plot time 0.006770833333333314
# on est dans le plot time 0.00679687499999998
# on est dans le plot time 0.006822916666666646
# on est dans le plot time 0.006848958333333313
# on est dans le plot time 0.006874999999999979
# on est dans le plot time 0.006901041666666646
# on est dans le plot time 0.006927083333333312
# on est dans le plot time 0.006953124999999978
# on est dans le plot time 0.006979166666666645
# on est dans le plot time 0.007005208333333311
# on est dans le plot time 0.007031249999999978
# on est dans le plot time 0.007057291666666644
# on est dans le plot time 0.00708333333333331
# on est dans le plot time 0.007109374999999977
# on est dans le plot time 0.007135416666666643
# on est dans le plot time 0.00716145833333331
# on est dans le plot time 0.007187499999999976
# on est dans le plot time 0.007213541666666642
# on est dans le plot time 0.007239583333333309
# on est dans le plot time 0.007265624999999975
# on est dans le plot time 0.007291666666666642
# on est dans le plot time 0.007317708333333308
# on est dans le plot time 0.007343749999999974
# on est dans le plot time 0.007369791666666641
# on est dans le plot time 0.007395833333333307
# on est dans le plot time 0.007421874999999974
# on est dans le plot time 0.00744791666666664
# on est dans le plot time 0.007473958333333306
# on est dans le plot time 0.007499999999999973
# on est dans le plot time 0.007526041666666639
# on est dans le plot time 0.007552083333333306
# on est dans le plot time 0.007578124999999972
# on est dans le plot time 0.0076041666666666384
# on est dans le plot time 0.007630208333333305
# on est dans le plot time 0.007656249999999971
# on est dans le plot time 0.007682291666666638
# on est dans le plot time 0.007708333333333304
# on est dans le plot time 0.0077343749999999704
# on est dans le plot time 0.007760416666666637
# on est dans le plot time 0.007786458333333303
# on est dans le plot time 0.00781249999999997
# on est dans le plot time 0.007838541666666636
# on est dans le plot time 0.007864583333333303
# on est dans le plot time 0.00789062499999997
# on est dans le plot time 0.007916666666666638
# on est dans le plot time 0.007942708333333305
# on est dans le plot time 0.007968749999999972
# on est dans le plot time 0.00799479166666664
# on est dans le plot time 0.008020833333333307
# on est dans le plot time 0.008046874999999974
# on est dans le plot time 0.008072916666666641
# on est dans le plot time 0.008098958333333309
# on est dans le plot time 0.008124999999999976
# on est dans le plot time 0.008151041666666643
# on est dans le plot time 0.00817708333333331
# on est dans le plot time 0.008203124999999978
# on est dans le plot time 0.008229166666666645
# on est dans le plot time 0.008255208333333312
# on est dans le plot time 0.00828124999999998
# on est dans le plot time 0.008307291666666647
# on est dans le plot time 0.008333333333333314
# on est dans le plot time 0.008359374999999981
# on est dans le plot time 0.008385416666666649
# on est dans le plot time 0.008411458333333316
# on est dans le plot time 0.008437499999999983
# on est dans le plot time 0.00846354166666665
# on est dans le plot time 0.008489583333333318
# on est dans le plot time 0.008515624999999985
# on est dans le plot time 0.008541666666666652
# on est dans le plot time 0.00856770833333332
# on est dans le plot time 0.008593749999999987
# on est dans le plot time 0.008619791666666654
# on est dans le plot time 0.008645833333333321
# on est dans le plot time 0.008671874999999989
# on est dans le plot time 0.008697916666666656
# on est dans le plot time 0.008723958333333323
# on est dans le plot time 0.00874999999999999
# on est dans le plot time 0.008776041666666658
# on est dans le plot time 0.008802083333333325
# on est dans le plot time 0.008828124999999992
# on est dans le plot time 0.00885416666666666
# on est dans le plot time 0.008880208333333327
# on est dans le plot time 0.008906249999999994
# on est dans le plot time 0.008932291666666661
# on est dans le plot time 0.008958333333333329
# on est dans le plot time 0.008984374999999996
# on est dans le plot time 0.009010416666666663
# on est dans le plot time 0.00903645833333333
# on est dans le plot time 0.009062499999999998
# on est dans le plot time 0.009088541666666665
# on est dans le plot time 0.009114583333333332
# on est dans le plot time 0.009140625
# on est dans le plot time 0.009166666666666667
# on est dans le plot time 0.009192708333333334
# on est dans le plot time 0.009218750000000001
# on est dans le plot time 0.009244791666666669
# on est dans le plot time 0.009270833333333336
# on est dans le plot time 0.009296875000000003
# on est dans le plot time 0.00932291666666667
# on est dans le plot time 0.009348958333333338
# on est dans le plot time 0.009375000000000005
# on est dans le plot time 0.009401041666666672
# on est dans le plot time 0.00942708333333334
# on est dans le plot time 0.009453125000000007
# on est dans le plot time 0.009479166666666674
# on est dans le plot time 0.009505208333333341
# on est dans le plot time 0.009531250000000008
# on est dans le plot time 0.009557291666666676
# on est dans le plot time 0.009583333333333343
# on est dans le plot time 0.00960937500000001
# on est dans le plot time 0.009635416666666678
# on est dans le plot time 0.009661458333333345
# on est dans le plot time 0.009687500000000012
# on est dans le plot time 0.00971354166666668
# on est dans le plot time 0.009739583333333347
# on est dans le plot time 0.009765625000000014
# on est dans le plot time 0.009791666666666681
# on est dans le plot time 0.009817708333333348
# on est dans le plot time 0.009843750000000016
# on est dans le plot time 0.009869791666666683
# on est dans le plot time 0.00989583333333335
# on est dans le plot time 0.009921875000000017
# on est dans le plot time 0.009947916666666685
# on est dans le plot time 0.009973958333333352
# on est dans le plot time 0.01000000000000002
# on est dans le plot time 0.010026041666666687
# on est dans le plot time 0.010052083333333354
# on est dans le plot time 0.010078125000000021
# on est dans le plot time 0.010104166666666688
# on est dans le plot time 0.010130208333333356
# on est dans le plot time 0.010156250000000023
# on est dans le plot time 0.01018229166666669
# on est dans le plot time 0.010208333333333357
# on est dans le plot time 0.010234375000000025
# on est dans le plot time 0.010260416666666692
# on est dans le plot time 0.01028645833333336
# on est dans le plot time 0.010312500000000027
# on est dans le plot time 0.010338541666666694
# on est dans le plot time 0.010364583333333361
# on est dans le plot time 0.010390625000000028
# on est dans le plot time 0.010416666666666696
# on est dans le plot time 0.010442708333333363
# on est dans le plot time 0.01046875000000003
# on est dans le plot time 0.010494791666666697
# on est dans le plot time 0.010520833333333365
# on est dans le plot time 0.010546875000000032
# on est dans le plot time 0.0105729166666667
# on est dans le plot time 0.010598958333333366
# on est dans le plot time 0.010625000000000034
# on est dans le plot time 0.010651041666666701
# on est dans le plot time 0.010677083333333368
# on est dans le plot time 0.010703125000000036
# on est dans le plot time 0.010729166666666703
# on est dans le plot time 0.01075520833333337
# on est dans le plot time 0.010781250000000037
# on est dans le plot time 0.010807291666666705
# on est dans le plot time 0.010833333333333372
# on est dans le plot time 0.01085937500000004
# on est dans le plot time 0.010885416666666706
# on est dans le plot time 0.010911458333333374
# on est dans le plot time 0.010937500000000041
# on est dans le plot time 0.010963541666666708
# on est dans le plot time 0.010989583333333375
# on est dans le plot time 0.011015625000000043
# on est dans le plot time 0.01104166666666671
# on est dans le plot time 0.011067708333333377
# on est dans le plot time 0.011093750000000045
# on est dans le plot time 0.011119791666666712
# on est dans le plot time 0.011145833333333379
# on est dans le plot time 0.011171875000000046
# on est dans le plot time 0.011197916666666714
# on est dans le plot time 0.011223958333333381
# on est dans le plot time 0.011250000000000048
# on est dans le plot time 0.011276041666666715
# on est dans le plot time 0.011302083333333383
# on est dans le plot time 0.01132812500000005
# on est dans le plot time 0.011354166666666717
# on est dans le plot time 0.011380208333333384
# on est dans le plot time 0.011406250000000052
# on est dans le plot time 0.011432291666666719
# on est dans le plot time 0.011458333333333386
# on est dans le plot time 0.011484375000000054
# on est dans le plot time 0.01151041666666672
# on est dans le plot time 0.011536458333333388
# on est dans le plot time 0.011562500000000055
# on est dans le plot time 0.011588541666666723
# on est dans le plot time 0.01161458333333339
# on est dans le plot time 0.011640625000000057
# on est dans le plot time 0.011666666666666724
# on est dans le plot time 0.011692708333333392
# on est dans le plot time 0.011718750000000059
# on est dans le plot time 0.011744791666666726
# on est dans le plot time 0.011770833333333394
# on est dans le plot time 0.01179687500000006
# on est dans le plot time 0.011822916666666728
# on est dans le plot time 0.011848958333333395
# on est dans le plot time 0.011875000000000063
# on est dans le plot time 0.01190104166666673
# on est dans le plot time 0.011927083333333397
# on est dans le plot time 0.011953125000000064
# on est dans le plot time 0.011979166666666732
# on est dans le plot time 0.012005208333333399
# on est dans le plot time 0.012031250000000066
# on est dans le plot time 0.012057291666666733
# on est dans le plot time 0.0120833333333334
# on est dans le plot time 0.012109375000000068
# on est dans le plot time 0.012135416666666735
# on est dans le plot time 0.012161458333333403
# on est dans le plot time 0.01218750000000007
# on est dans le plot time 0.012213541666666737
# on est dans le plot time 0.012239583333333404
# on est dans le plot time 0.012265625000000072
# on est dans le plot time 0.012291666666666739
# on est dans le plot time 0.012317708333333406
# on est dans le plot time 0.012343750000000073
# on est dans le plot time 0.01236979166666674
# on est dans le plot time 0.012395833333333408
# on est dans le plot time 0.012421875000000075
# on est dans le plot time 0.012447916666666742
# on est dans le plot time 0.01247395833333341
# on est dans le plot time 0.012500000000000077
# on est dans le plot time 0.012526041666666744
# on est dans le plot time 0.012552083333333412
# on est dans le plot time 0.012578125000000079
# on est dans le plot time 0.012604166666666746
# on est dans le plot time 0.012630208333333413
# on est dans le plot time 0.01265625000000008
# on est dans le plot time 0.012682291666666748
# on est dans le plot time 0.012708333333333415
# on est dans le plot time 0.012734375000000082
# on est dans le plot time 0.01276041666666675
# on est dans le plot time 0.012786458333333417
# on est dans le plot time 0.012812500000000084
# on est dans le plot time 0.012838541666666752
# on est dans le plot time 0.012864583333333419
# on est dans le plot time 0.012890625000000086
# on est dans le plot time 0.012916666666666753
# on est dans le plot time 0.01294270833333342
# on est dans le plot time 0.012968750000000088
# on est dans le plot time 0.012994791666666755
# on est dans le plot time 0.013020833333333422
# on est dans le plot time 0.01304687500000009
# on est dans le plot time 0.013072916666666757
# on est dans le plot time 0.013098958333333424
# on est dans le plot time 0.013125000000000091
# on est dans le plot time 0.013151041666666759
# on est dans le plot time 0.013177083333333426
# on est dans le plot time 0.013203125000000093
# on est dans le plot time 0.01322916666666676
# on est dans le plot time 0.013255208333333428
# on est dans le plot time 0.013281250000000095
# on est dans le plot time 0.013307291666666762
# on est dans le plot time 0.01333333333333343
# on est dans le plot time 0.013359375000000097
# on est dans le plot time 0.013385416666666764
# on est dans le plot time 0.013411458333333431
# on est dans le plot time 0.013437500000000099
# on est dans le plot time 0.013463541666666766
# on est dans le plot time 0.013489583333333433
# on est dans le plot time 0.0135156250000001
# on est dans le plot time 0.013541666666666768
# on est dans le plot time 0.013567708333333435
# on est dans le plot time 0.013593750000000102
# on est dans le plot time 0.01361979166666677
# on est dans le plot time 0.013645833333333437
# on est dans le plot time 0.013671875000000104
# on est dans le plot time 0.013697916666666771
# on est dans le plot time 0.013723958333333439
# on est dans le plot time 0.013750000000000106
# on est dans le plot time 0.013776041666666773
# on est dans le plot time 0.01380208333333344
# on est dans le plot time 0.013828125000000108
# on est dans le plot time 0.013854166666666775
# on est dans le plot time 0.013880208333333442
# on est dans le plot time 0.01390625000000011
# on est dans le plot time 0.013932291666666777
# on est dans le plot time 0.013958333333333444
# on est dans le plot time 0.013984375000000111
# on est dans le plot time 0.014010416666666779
# on est dans le plot time 0.014036458333333446
# on est dans le plot time 0.014062500000000113
# on est dans le plot time 0.01408854166666678
# on est dans le plot time 0.014114583333333448
# on est dans le plot time 0.014140625000000115
# on est dans le plot time 0.014166666666666782
# on est dans le plot time 0.01419270833333345
# on est dans le plot time 0.014218750000000117
# on est dans le plot time 0.014244791666666784
# on est dans le plot time 0.014270833333333451
# on est dans le plot time 0.014296875000000119
# on est dans le plot time 0.014322916666666786
# on est dans le plot time 0.014348958333333453
# on est dans le plot time 0.01437500000000012
# on est dans le plot time 0.014401041666666788
# on est dans le plot time 0.014427083333333455
# on est dans le plot time 0.014453125000000122
# on est dans le plot time 0.01447916666666679
# on est dans le plot time 0.014505208333333457
# on est dans le plot time 0.014531250000000124
# on est dans le plot time 0.014557291666666791
# on est dans le plot time 0.014583333333333458
# on est dans le plot time 0.014609375000000126
# on est dans le plot time 0.014635416666666793
# on est dans le plot time 0.01466145833333346
# on est dans le plot time 0.014687500000000128
# on est dans le plot time 0.014713541666666795
# on est dans le plot time 0.014739583333333462
# on est dans le plot time 0.01476562500000013
# on est dans le plot time 0.014791666666666797
# on est dans le plot time 0.014817708333333464
# on est dans le plot time 0.014843750000000131
# on est dans le plot time 0.014869791666666798
# on est dans le plot time 0.014895833333333466
# on est dans le plot time 0.014921875000000133
# on est dans le plot time 0.0149479166666668
# on est dans le plot time 0.014973958333333467
# on est dans le plot time 0.015000000000000135
# on est dans le plot time 0.015026041666666802
# on est dans le plot time 0.01505208333333347
# on est dans le plot time 0.015078125000000137
# on est dans le plot time 0.015104166666666804
# on est dans le plot time 0.015130208333333471
# on est dans le plot time 0.015156250000000138
# on est dans le plot time 0.015182291666666806
# on est dans le plot time 0.015208333333333473
# on est dans le plot time 0.01523437500000014
# on est dans le plot time 0.015260416666666807
# on est dans le plot time 0.015286458333333475
# on est dans le plot time 0.015312500000000142
# on est dans le plot time 0.01533854166666681
# on est dans le plot time 0.015364583333333477
# on est dans le plot time 0.015390625000000144
# on est dans le plot time 0.015416666666666811
# on est dans le plot time 0.015442708333333478
# on est dans le plot time 0.015468750000000146
# on est dans le plot time 0.015494791666666813
# on est dans le plot time 0.01552083333333348
# on est dans le plot time 0.015546875000000147
# on est dans le plot time 0.015572916666666815
# on est dans le plot time 0.015598958333333482
# on est dans le plot time 0.01562500000000015
# on est dans le plot time 0.015651041666666816
# on est dans le plot time 0.015677083333333484
# on est dans le plot time 0.01570312500000015
# on est dans le plot time 0.015729166666666818
# on est dans le plot time 0.015755208333333486
# on est dans le plot time 0.015781250000000153
# on est dans le plot time 0.01580729166666682
# on est dans le plot time 0.015833333333333487
# on est dans le plot time 0.015859375000000155
# on est dans le plot time 0.015885416666666822
# on est dans le plot time 0.01591145833333349
# on est dans le plot time 0.015937500000000156
# on est dans le plot time 0.015963541666666824
# on est dans le plot time 0.01598958333333349
# on est dans le plot time 0.016015625000000158
# on est dans le plot time 0.016041666666666825
# on est dans le plot time 0.016067708333333493
# on est dans le plot time 0.01609375000000016
# on est dans le plot time 0.016119791666666827
# on est dans le plot time 0.016145833333333495
# on est dans le plot time 0.016171875000000162
# on est dans le plot time 0.01619791666666683
# on est dans le plot time 0.016223958333333496
# on est dans le plot time 0.016250000000000164
# on est dans le plot time 0.01627604166666683
# on est dans le plot time 0.016302083333333498
# on est dans le plot time 0.016328125000000165
# on est dans le plot time 0.016354166666666833
# on est dans le plot time 0.0163802083333335
# on est dans le plot time 0.016406250000000167
# on est dans le plot time 0.016432291666666834
# on est dans le plot time 0.016458333333333502
# on est dans le plot time 0.01648437500000017
# on est dans le plot time 0.016510416666666836
# on est dans le plot time 0.016536458333333504
# on est dans le plot time 0.01656250000000017
# on est dans le plot time 0.016588541666666838
# on est dans le plot time 0.016614583333333505
# on est dans le plot time 0.016640625000000173
# on est dans le plot time 0.01666666666666684
# on est dans le plot time 0.016692708333333507
# on est dans le plot time 0.016718750000000174
# on est dans le plot time 0.01674479166666684
# on est dans le plot time 0.01677083333333351
# on est dans le plot time 0.016796875000000176
# on est dans le plot time 0.016822916666666844
# on est dans le plot time 0.01684895833333351
# on est dans le plot time 0.016875000000000178
# on est dans le plot time 0.016901041666666845
# on est dans le plot time 0.016927083333333513
# on est dans le plot time 0.01695312500000018
# on est dans le plot time 0.016979166666666847
# on est dans le plot time 0.017005208333333514
# on est dans le plot time 0.01703125000000018
# on est dans le plot time 0.01705729166666685
# on est dans le plot time 0.017083333333333516
# on est dans le plot time 0.017109375000000183
# on est dans le plot time 0.01713541666666685
# on est dans le plot time 0.017161458333333518
# on est dans le plot time 0.017187500000000185
# on est dans le plot time 0.017213541666666853
# on est dans le plot time 0.01723958333333352
# on est dans le plot time 0.017265625000000187
# on est dans le plot time 0.017291666666666854
# on est dans le plot time 0.01731770833333352
# on est dans le plot time 0.01734375000000019
# on est dans le plot time 0.017369791666666856
# on est dans le plot time 0.017395833333333523
# on est dans le plot time 0.01742187500000019
# on est dans le plot time 0.017447916666666858
# on est dans le plot time 0.017473958333333525
# on est dans le plot time 0.017500000000000192
# on est dans le plot time 0.01752604166666686
# on est dans le plot time 0.017552083333333527
# on est dans le plot time 0.017578125000000194
# on est dans le plot time 0.01760416666666686
# on est dans le plot time 0.01763020833333353
# on est dans le plot time 0.017656250000000196
# on est dans le plot time 0.017682291666666863
# on est dans le plot time 0.01770833333333353
# on est dans le plot time 0.017734375000000198
# on est dans le plot time 0.017760416666666865
# on est dans le plot time 0.017786458333333532
# on est dans le plot time 0.0178125000000002
# on est dans le plot time 0.017838541666666867
# on est dans le plot time 0.017864583333333534
# on est dans le plot time 0.0178906250000002
# on est dans le plot time 0.01791666666666687
# on est dans le plot time 0.017942708333333536
# on est dans le plot time 0.017968750000000203
# on est dans le plot time 0.01799479166666687
# on est dans le plot time 0.018020833333333538
# on est dans le plot time 0.018046875000000205
# on est dans le plot time 0.018072916666666872
# on est dans le plot time 0.01809895833333354
# on est dans le plot time 0.018125000000000207
# on est dans le plot time 0.018151041666666874
# on est dans le plot time 0.01817708333333354
# on est dans le plot time 0.01820312500000021
# on est dans le plot time 0.018229166666666876
# on est dans le plot time 0.018255208333333543
# on est dans le plot time 0.01828125000000021
# on est dans le plot time 0.018307291666666878
# on est dans le plot time 0.018333333333333545
# on est dans le plot time 0.018359375000000212
# on est dans le plot time 0.01838541666666688
# on est dans le plot time 0.018411458333333547
# on est dans le plot time 0.018437500000000214
# on est dans le plot time 0.01846354166666688
# on est dans le plot time 0.01848958333333355
# on est dans le plot time 0.018515625000000216
# on est dans le plot time 0.018541666666666883
# on est dans le plot time 0.01856770833333355
# on est dans le plot time 0.018593750000000218
# on est dans le plot time 0.018619791666666885
# on est dans le plot time 0.018645833333333552
# on est dans le plot time 0.01867187500000022
# on est dans le plot time 0.018697916666666887
# on est dans le plot time 0.018723958333333554
# on est dans le plot time 0.01875000000000022
# on est dans le plot time 0.01877604166666689
# on est dans le plot time 0.018802083333333556
# on est dans le plot time 0.018828125000000223
# on est dans le plot time 0.01885416666666689
# on est dans le plot time 0.018880208333333558
# on est dans le plot time 0.018906250000000225
# on est dans le plot time 0.018932291666666892
# on est dans le plot time 0.01895833333333356
# on est dans le plot time 0.018984375000000227
# on est dans le plot time 0.019010416666666894
# on est dans le plot time 0.01903645833333356
# on est dans le plot time 0.01906250000000023
# on est dans le plot time 0.019088541666666896
# on est dans le plot time 0.019114583333333563
# on est dans le plot time 0.01914062500000023
# on est dans le plot time 0.019166666666666898
# on est dans le plot time 0.019192708333333565
# on est dans le plot time 0.019218750000000232
# on est dans le plot time 0.0192447916666669
# on est dans le plot time 0.019270833333333567
# on est dans le plot time 0.019296875000000234
# on est dans le plot time 0.0193229166666669
# on est dans le plot time 0.01934895833333357
# on est dans le plot time 0.019375000000000236
# on est dans le plot time 0.019401041666666903
# on est dans le plot time 0.01942708333333357
# on est dans le plot time 0.019453125000000238
# on est dans le plot time 0.019479166666666905
# on est dans le plot time 0.019505208333333572
# on est dans le plot time 0.01953125000000024
# on est dans le plot time 0.019557291666666907
# on est dans le plot time 0.019583333333333574
# on est dans le plot time 0.01960937500000024
# on est dans le plot time 0.01963541666666691
# on est dans le plot time 0.019661458333333576
# on est dans le plot time 0.019687500000000243
# on est dans le plot time 0.01971354166666691
# on est dans le plot time 0.019739583333333578
# on est dans le plot time 0.019765625000000245
# on est dans le plot time 0.019791666666666912
# on est dans le plot time 0.01981770833333358
# on est dans le plot time 0.019843750000000247
# on est dans le plot time 0.019869791666666914
# on est dans le plot time 0.01989583333333358
# on est dans le plot time 0.01992187500000025
# on est dans le plot time 0.019947916666666916
# on est dans le plot time 0.019973958333333583
# on est dans le plot time 0.02000000000000025
# on est dans le plot time 0.020026041666666917
# on est dans le plot time 0.020052083333333585
# on est dans le plot time 0.020078125000000252
# on est dans le plot time 0.02010416666666692
# on est dans le plot time 0.020130208333333587
# on est dans le plot time 0.020156250000000254
# on est dans le plot time 0.02018229166666692
# on est dans le plot time 0.02020833333333359
# on est dans le plot time 0.020234375000000256
# on est dans le plot time 0.020260416666666923
# on est dans le plot time 0.02028645833333359
# on est dans le plot time 0.020312500000000257
# on est dans le plot time 0.020338541666666925
# on est dans le plot time 0.020364583333333592
# on est dans le plot time 0.02039062500000026
# on est dans le plot time 0.020416666666666927
# on est dans le plot time 0.020442708333333594
# on est dans le plot time 0.02046875000000026
# on est dans le plot time 0.02049479166666693
# on est dans le plot time 0.020520833333333596
# on est dans le plot time 0.020546875000000263
# on est dans le plot time 0.02057291666666693
# on est dans le plot time 0.020598958333333597
# on est dans le plot time 0.020625000000000265
# on est dans le plot time 0.020651041666666932
# on est dans le plot time 0.0206770833333336
# on est dans le plot time 0.020703125000000266
# on est dans le plot time 0.020729166666666934
# on est dans le plot time 0.0207552083333336
# on est dans le plot time 0.020781250000000268
# on est dans le plot time 0.020807291666666936
# on est dans le plot time 0.020833333333333603
# on est dans le plot time 0.02085937500000027
# on est dans le plot time 0.020885416666666937
# on est dans le plot time 0.020911458333333605
# on est dans le plot time 0.020937500000000272
# on est dans le plot time 0.02096354166666694
# on est dans le plot time 0.020989583333333606
# on est dans le plot time 0.021015625000000274
# on est dans le plot time 0.02104166666666694
# on est dans le plot time 0.021067708333333608
# on est dans le plot time 0.021093750000000275
# on est dans le plot time 0.021119791666666943
# on est dans le plot time 0.02114583333333361
# on est dans le plot time 0.021171875000000277
# on est dans le plot time 0.021197916666666945
# on est dans le plot time 0.021223958333333612
# on est dans le plot time 0.02125000000000028
# on est dans le plot time 0.021276041666666946
# on est dans le plot time 0.021302083333333614
# on est dans le plot time 0.02132812500000028
# on est dans le plot time 0.021354166666666948
# on est dans le plot time 0.021380208333333615
# on est dans le plot time 0.021406250000000283
# on est dans le plot time 0.02143229166666695
# on est dans le plot time 0.021458333333333617
# on est dans le plot time 0.021484375000000284
# on est dans le plot time 0.021510416666666952
# on est dans le plot time 0.02153645833333362
# on est dans le plot time 0.021562500000000286
# on est dans le plot time 0.021588541666666954
# on est dans le plot time 0.02161458333333362
# on est dans le plot time 0.021640625000000288
# on est dans le plot time 0.021666666666666955
# on est dans le plot time 0.021692708333333623
# on est dans le plot time 0.02171875000000029
# on est dans le plot time 0.021744791666666957
# on est dans le plot time 0.021770833333333624
# on est dans le plot time 0.02179687500000029
# on est dans le plot time 0.02182291666666696
# on est dans le plot time 0.021848958333333626
# on est dans le plot time 0.021875000000000294
# on est dans le plot time 0.02190104166666696
# on est dans le plot time 0.021927083333333628
# on est dans le plot time 0.021953125000000295
# on est dans le plot time 0.021979166666666963
# on est dans le plot time 0.02200520833333363
# on est dans le plot time 0.022031250000000297
# on est dans le plot time 0.022057291666666964
# on est dans le plot time 0.02208333333333363
# on est dans le plot time 0.0221093750000003
# on est dans le plot time 0.022135416666666966
# on est dans le plot time 0.022161458333333633
# on est dans le plot time 0.0221875000000003
# on est dans le plot time 0.022213541666666968
# on est dans le plot time 0.022239583333333635
# on est dans le plot time 0.022265625000000303
# on est dans le plot time 0.02229166666666697
# on est dans le plot time 0.022317708333333637
# on est dans le plot time 0.022343750000000304
# on est dans le plot time 0.02236979166666697
# on est dans le plot time 0.02239583333333364
# on est dans le plot time 0.022421875000000306
# on est dans le plot time 0.022447916666666973
# on est dans le plot time 0.02247395833333364
# on est dans le plot time 0.022500000000000308
# on est dans le plot time 0.022526041666666975
# on est dans le plot time 0.022552083333333642
# on est dans le plot time 0.02257812500000031
# on est dans le plot time 0.022604166666666977
# on est dans le plot time 0.022630208333333644
# on est dans le plot time 0.02265625000000031
# on est dans le plot time 0.02268229166666698
# on est dans le plot time 0.022708333333333646
# on est dans le plot time 0.022734375000000313
# on est dans le plot time 0.02276041666666698
# on est dans le plot time 0.022786458333333648
# on est dans le plot time 0.022812500000000315
# on est dans le plot time 0.022838541666666982
# on est dans le plot time 0.02286458333333365
# on est dans le plot time 0.022890625000000317
# on est dans le plot time 0.022916666666666984
# on est dans le plot time 0.02294270833333365
# on est dans le plot time 0.02296875000000032
# on est dans le plot time 0.022994791666666986
# on est dans le plot time 0.023020833333333653
# on est dans le plot time 0.02304687500000032
# on est dans le plot time 0.023072916666666988
# on est dans le plot time 0.023098958333333655
# on est dans le plot time 0.023125000000000322
# on est dans le plot time 0.02315104166666699
# on est dans le plot time 0.023177083333333657
# on est dans le plot time 0.023203125000000324
# on est dans le plot time 0.02322916666666699
# on est dans le plot time 0.02325520833333366
# on est dans le plot time 0.023281250000000326
# on est dans le plot time 0.023307291666666993
# on est dans le plot time 0.02333333333333366
# on est dans le plot time 0.023359375000000328
# on est dans le plot time 0.023385416666666995
# on est dans le plot time 0.023411458333333662
# on est dans le plot time 0.02343750000000033
# on est dans le plot time 0.023463541666666997
# on est dans le plot time 0.023489583333333664
# on est dans le plot time 0.02351562500000033
# on est dans le plot time 0.023541666666667
# on est dans le plot time 0.023567708333333666
# on est dans le plot time 0.023593750000000333
# on est dans le plot time 0.023619791666667
# on est dans le plot time 0.023645833333333668
# on est dans le plot time 0.023671875000000335
# on est dans le plot time 0.023697916666667002
# on est dans le plot time 0.02372395833333367
# on est dans le plot time 0.023750000000000337
# on est dans le plot time 0.023776041666667004
# on est dans le plot time 0.02380208333333367
# on est dans le plot time 0.02382812500000034
# on est dans le plot time 0.023854166666667006
# on est dans le plot time 0.023880208333333673
# on est dans le plot time 0.02390625000000034
# on est dans le plot time 0.023932291666667008
# on est dans le plot time 0.023958333333333675
# on est dans le plot time 0.023984375000000342
# on est dans le plot time 0.02401041666666701
# on est dans le plot time 0.024036458333333677
# on est dans le plot time 0.024062500000000344
# on est dans le plot time 0.02408854166666701
# on est dans le plot time 0.02411458333333368
# on est dans le plot time 0.024140625000000346
# on est dans le plot time 0.024166666666667013
# on est dans le plot time 0.02419270833333368
# on est dans le plot time 0.024218750000000348
# on est dans le plot time 0.024244791666667015
# on est dans le plot time 0.024270833333333682
# on est dans le plot time 0.02429687500000035
# on est dans le plot time 0.024322916666667017
# on est dans le plot time 0.024348958333333684
# on est dans le plot time 0.02437500000000035
# on est dans le plot time 0.02440104166666702
# on est dans le plot time 0.024427083333333686
# on est dans le plot time 0.024453125000000353
# on est dans le plot time 0.02447916666666702
# on est dans le plot time 0.024505208333333688
# on est dans le plot time 0.024531250000000355
# on est dans le plot time 0.024557291666667022
# on est dans le plot time 0.02458333333333369
# on est dans le plot time 0.024609375000000357
# on est dans le plot time 0.024635416666667024
# on est dans le plot time 0.02466145833333369
# on est dans le plot time 0.02468750000000036
# on est dans le plot time 0.024713541666667026
# on est dans le plot time 0.024739583333333693
# on est dans le plot time 0.02476562500000036
# on est dans le plot time 0.024791666666667028
# on est dans le plot time 0.024817708333333695
# on est dans le plot time 0.024843750000000362
# on est dans le plot time 0.02486979166666703
# on est dans le plot time 0.024895833333333697
# on est dans le plot time 0.024921875000000364
# on est dans le plot time 0.02494791666666703
# on est dans le plot time 0.0249739583333337
# on est dans le plot time 0.025000000000000366
# on est dans le plot time 0.025026041666667033
# on est dans le plot time 0.0250520833333337
# on est dans le plot time 0.025078125000000367
# on est dans le plot time 0.025104166666667035
# on est dans le plot time 0.025130208333333702
# on est dans le plot time 0.02515625000000037
# on est dans le plot time 0.025182291666667037
# on est dans le plot time 0.025208333333333704
# on est dans le plot time 0.02523437500000037
# on est dans le plot time 0.02526041666666704
# on est dans le plot time 0.025286458333333706
# on est dans le plot time 0.025312500000000373
# on est dans le plot time 0.02533854166666704
# on est dans le plot time 0.025364583333333707
# on est dans le plot time 0.025390625000000375
# on est dans le plot time 0.025416666666667042
# on est dans le plot time 0.02544270833333371
# on est dans le plot time 0.025468750000000377
# on est dans le plot time 0.025494791666667044
# on est dans le plot time 0.02552083333333371
# on est dans le plot time 0.02554687500000038
# on est dans le plot time 0.025572916666667046
# on est dans le plot time 0.025598958333333713
# on est dans le plot time 0.02562500000000038
# on est dans le plot time 0.025651041666667047
# on est dans le plot time 0.025677083333333715
# on est dans le plot time 0.025703125000000382
# on est dans le plot time 0.02572916666666705
# on est dans le plot time 0.025755208333333716
# on est dans le plot time 0.025781250000000384
# on est dans le plot time 0.02580729166666705
# on est dans le plot time 0.025833333333333718
# on est dans le plot time 0.025859375000000386
# on est dans le plot time 0.025885416666667053
# on est dans le plot time 0.02591145833333372
# on est dans le plot time 0.025937500000000387
# on est dans le plot time 0.025963541666667055
# on est dans le plot time 0.025989583333333722
# on est dans le plot time 0.02601562500000039
# on est dans le plot time 0.026041666666667056
# on est dans le plot time 0.026067708333333724
# on est dans le plot time 0.02609375000000039
# on est dans le plot time 0.026119791666667058
# on est dans le plot time 0.026145833333333725
# on est dans le plot time 0.026171875000000393
# on est dans le plot time 0.02619791666666706
# on est dans le plot time 0.026223958333333727
# on est dans le plot time 0.026250000000000395
# on est dans le plot time 0.026276041666667062
# on est dans le plot time 0.02630208333333373
# on est dans le plot time 0.026328125000000396
# on est dans le plot time 0.026354166666667064
# on est dans le plot time 0.02638020833333373
# on est dans le plot time 0.026406250000000398
# on est dans le plot time 0.026432291666667065
# on est dans le plot time 0.026458333333333733
# on est dans le plot time 0.0264843750000004
# on est dans le plot time 0.026510416666667067
# on est dans le plot time 0.026536458333333734
# on est dans le plot time 0.026562500000000402
# on est dans le plot time 0.02658854166666707
# on est dans le plot time 0.026614583333333736
# on est dans le plot time 0.026640625000000404
# on est dans le plot time 0.02666666666666707
# on est dans le plot time 0.026692708333333738
# on est dans le plot time 0.026718750000000405
# on est dans le plot time 0.026744791666667073
# on est dans le plot time 0.02677083333333374
# on est dans le plot time 0.026796875000000407
# on est dans le plot time 0.026822916666667074
# on est dans le plot time 0.02684895833333374
# on est dans le plot time 0.02687500000000041
# on est dans le plot time 0.026901041666667076
# on est dans le plot time 0.026927083333333744
# on est dans le plot time 0.02695312500000041
# on est dans le plot time 0.026979166666667078
# on est dans le plot time 0.027005208333333745
# on est dans le plot time 0.027031250000000413
# on est dans le plot time 0.02705729166666708
# on est dans le plot time 0.027083333333333747
# on est dans le plot time 0.027109375000000414
# on est dans le plot time 0.02713541666666708
# on est dans le plot time 0.02716145833333375
# on est dans le plot time 0.027187500000000416
# on est dans le plot time 0.027213541666667083
# ...
# on est dans le plot time 1.514843749998876
# on est dans le plot time 1.5148697916655427
# on est dans le plot time 1.5148958333322093
# on est dans le plot time 1.514921874998876
# on est dans le plot time 1.5149479166655426
# on est dans le plot time 1.5149739583322093
# on est dans le plot time 1.514999999998876
# on est dans le plot time 1.5150260416655426
# on est dans le plot time 1.5150520833322092
# on est dans le plot time 1.5150781249988758
# on est dans le plot time 1.5151041666655425
# on est dans le plot time 1.5151302083322091
# on est dans le plot time 1.5151562499988758
# on est dans le plot time 1.5151822916655424
# on est dans le plot time 1.515208333332209
# on est dans le plot time 1.5152343749988757
# on est dans le plot time 1.5152604166655423
# on est dans le plot time 1.515286458332209
# on est dans le plot time 1.5153124999988756
# on est dans le plot time 1.5153385416655423
# on est dans le plot time 1.515364583332209
# on est dans le plot time 1.5153906249988756
# on est dans le plot time 1.5154166666655422
# on est dans le plot time 1.5154427083322088
# on est dans le plot time 1.5154687499988755
# on est dans le plot time 1.5154947916655421
# on est dans le plot time 1.5155208333322088
# on est dans le plot time 1.5155468749988754
# on est dans le plot time 1.515572916665542
# on est dans le plot time 1.5155989583322087
# on est dans le plot time 1.5156249999988753
# on est dans le plot time 1.515651041665542
# on est dans le plot time 1.5156770833322086
# on est dans le plot time 1.5157031249988753
# on est dans le plot time 1.515729166665542
# on est dans le plot time 1.5157552083322086
# on est dans le plot time 1.5157812499988752
# on est dans le plot time 1.5158072916655418
# on est dans le plot time 1.5158333333322085
# on est dans le plot time 1.5158593749988751
# on est dans le plot time 1.5158854166655418
# on est dans le plot time 1.5159114583322084
# on est dans le plot time 1.515937499998875
# on est dans le plot time 1.5159635416655417
# on est dans le plot time 1.5159895833322083
# on est dans le plot time 1.516015624998875
# on est dans le plot time 1.5160416666655416
# on est dans le plot time 1.5160677083322083
# on est dans le plot time 1.516093749998875
# on est dans le plot time 1.5161197916655416
# on est dans le plot time 1.5161458333322082
# on est dans le plot time 1.5161718749988748
# on est dans le plot time 1.5161979166655415
# on est dans le plot time 1.5162239583322081
# on est dans le plot time 1.5162499999988748
# on est dans le plot time 1.5162760416655414
# on est dans le plot time 1.516302083332208
# on est dans le plot time 1.5163281249988747
# on est dans le plot time 1.5163541666655413
# on est dans le plot time 1.516380208332208
# on est dans le plot time 1.5164062499988746
# on est dans le plot time 1.5164322916655413
# on est dans le plot time 1.516458333332208
# on est dans le plot time 1.5164843749988746
# on est dans le plot time 1.5165104166655412
# on est dans le plot time 1.5165364583322078
# on est dans le plot time 1.5165624999988745
# on est dans le plot time 1.5165885416655411
# on est dans le plot time 1.5166145833322078
# on est dans le plot time 1.5166406249988744
# on est dans le plot time 1.516666666665541
# on est dans le plot time 1.5166927083322077
# on est dans le plot time 1.5167187499988743
# on est dans le plot time 1.516744791665541
# on est dans le plot time 1.5167708333322076
# on est dans le plot time 1.5167968749988743
# on est dans le plot time 1.516822916665541
# on est dans le plot time 1.5168489583322076
# on est dans le plot time 1.5168749999988742
# on est dans le plot time 1.5169010416655409
# on est dans le plot time 1.5169270833322075
# on est dans le plot time 1.5169531249988741
# on est dans le plot time 1.5169791666655408
# on est dans le plot time 1.5170052083322074
# on est dans le plot time 1.517031249998874
# on est dans le plot time 1.5170572916655407
# on est dans le plot time 1.5170833333322074
# on est dans le plot time 1.517109374998874
# on est dans le plot time 1.5171354166655406
# on est dans le plot time 1.5171614583322073
# on est dans le plot time 1.517187499998874
# on est dans le plot time 1.5172135416655406
# on est dans le plot time 1.5172395833322072
# on est dans le plot time 1.5172656249988739
# on est dans le plot time 1.5172916666655405
# on est dans le plot time 1.5173177083322071
# on est dans le plot time 1.5173437499988738
# on est dans le plot time 1.5173697916655404
# on est dans le plot time 1.517395833332207
# on est dans le plot time 1.5174218749988737
# on est dans le plot time 1.5174479166655404
# on est dans le plot time 1.517473958332207
# on est dans le plot time 1.5174999999988736
# on est dans le plot time 1.5175260416655403
# on est dans le plot time 1.517552083332207
# on est dans le plot time 1.5175781249988736
# on est dans le plot time 1.5176041666655402
# on est dans le plot time 1.5176302083322069
# on est dans le plot time 1.5176562499988735
# on est dans le plot time 1.5176822916655401
# on est dans le plot time 1.5177083333322068
# on est dans le plot time 1.5177343749988734
# on est dans le plot time 1.51776041666554
# on est dans le plot time 1.5177864583322067
# on est dans le plot time 1.5178124999988734
# on est dans le plot time 1.51783854166554
# on est dans le plot time 1.5178645833322066
# on est dans le plot time 1.5178906249988733
# on est dans le plot time 1.51791666666554
# on est dans le plot time 1.5179427083322066
# on est dans le plot time 1.5179687499988732
# on est dans le plot time 1.5179947916655399
# on est dans le plot time 1.5180208333322065
# on est dans le plot time 1.5180468749988731
# on est dans le plot time 1.5180729166655398
# on est dans le plot time 1.5180989583322064
# on est dans le plot time 1.518124999998873
# on est dans le plot time 1.5181510416655397
# on est dans le plot time 1.5181770833322064
# on est dans le plot time 1.518203124998873
# on est dans le plot time 1.5182291666655396
# on est dans le plot time 1.5182552083322063
# on est dans le plot time 1.518281249998873
# on est dans le plot time 1.5183072916655396
# on est dans le plot time 1.5183333333322062
# on est dans le plot time 1.5183593749988729
# on est dans le plot time 1.5183854166655395
# on est dans le plot time 1.5184114583322061
# on est dans le plot time 1.5184374999988728
# on est dans le plot time 1.5184635416655394
# on est dans le plot time 1.518489583332206
# on est dans le plot time 1.5185156249988727
# on est dans le plot time 1.5185416666655394
# on est dans le plot time 1.518567708332206
# on est dans le plot time 1.5185937499988726
# on est dans le plot time 1.5186197916655393
# on est dans le plot time 1.518645833332206
# on est dans le plot time 1.5186718749988726
# on est dans le plot time 1.5186979166655392
# on est dans le plot time 1.5187239583322059
# on est dans le plot time 1.5187499999988725
# on est dans le plot time 1.5187760416655391
# on est dans le plot time 1.5188020833322058
# on est dans le plot time 1.5188281249988724
# on est dans le plot time 1.518854166665539
# on est dans le plot time 1.5188802083322057
# on est dans le plot time 1.5189062499988724
# on est dans le plot time 1.518932291665539
# on est dans le plot time 1.5189583333322056
# on est dans le plot time 1.5189843749988723
# on est dans le plot time 1.519010416665539
# on est dans le plot time 1.5190364583322056
# on est dans le plot time 1.5190624999988722
# on est dans le plot time 1.5190885416655389
# on est dans le plot time 1.5191145833322055
# on est dans le plot time 1.5191406249988721
# on est dans le plot time 1.5191666666655388
# on est dans le plot time 1.5191927083322054
# on est dans le plot time 1.519218749998872
# on est dans le plot time 1.5192447916655387
# on est dans le plot time 1.5192708333322054
# on est dans le plot time 1.519296874998872
# on est dans le plot time 1.5193229166655386
# on est dans le plot time 1.5193489583322053
# on est dans le plot time 1.519374999998872
# on est dans le plot time 1.5194010416655386
# on est dans le plot time 1.5194270833322052
# on est dans le plot time 1.5194531249988719
# on est dans le plot time 1.5194791666655385
# on est dans le plot time 1.5195052083322051
# on est dans le plot time 1.5195312499988718
# on est dans le plot time 1.5195572916655384
# on est dans le plot time 1.519583333332205
# on est dans le plot time 1.5196093749988717
# on est dans le plot time 1.5196354166655384
# on est dans le plot time 1.519661458332205
# on est dans le plot time 1.5196874999988716
# on est dans le plot time 1.5197135416655383
# on est dans le plot time 1.519739583332205
# on est dans le plot time 1.5197656249988716
# on est dans le plot time 1.5197916666655382
# on est dans le plot time 1.5198177083322049
# on est dans le plot time 1.5198437499988715
# on est dans le plot time 1.5198697916655382
# on est dans le plot time 1.5198958333322048
# on est dans le plot time 1.5199218749988714
# on est dans le plot time 1.519947916665538
# on est dans le plot time 1.5199739583322047
# on est dans le plot time 1.5199999999988714
# on est dans le plot time 1.520026041665538
# on est dans le plot time 1.5200520833322047
# on est dans le plot time 1.5200781249988713
# on est dans le plot time 1.520104166665538
# on est dans le plot time 1.5201302083322046
# on est dans le plot time 1.5201562499988712
# on est dans le plot time 1.5201822916655379
# on est dans le plot time 1.5202083333322045
# on est dans le plot time 1.5202343749988712
# on est dans le plot time 1.5202604166655378
# on est dans le plot time 1.5202864583322044
# on est dans le plot time 1.520312499998871
# on est dans le plot time 1.5203385416655377
# on est dans le plot time 1.5203645833322044
# on est dans le plot time 1.520390624998871
# on est dans le plot time 1.5204166666655377
# on est dans le plot time 1.5204427083322043
# on est dans le plot time 1.520468749998871
# on est dans le plot time 1.5204947916655376
# on est dans le plot time 1.5205208333322042
# on est dans le plot time 1.5205468749988709
# on est dans le plot time 1.5205729166655375
# on est dans le plot time 1.5205989583322042
# on est dans le plot time 1.5206249999988708
# on est dans le plot time 1.5206510416655374
# on est dans le plot time 1.520677083332204
# on est dans le plot time 1.5207031249988707
# on est dans le plot time 1.5207291666655374
# on est dans le plot time 1.520755208332204
# on est dans le plot time 1.5207812499988707
# on est dans le plot time 1.5208072916655373
# on est dans le plot time 1.520833333332204
# on est dans le plot time 1.5208593749988706
# on est dans le plot time 1.5208854166655372
# on est dans le plot time 1.5209114583322039
# on est dans le plot time 1.5209374999988705
# on est dans le plot time 1.5209635416655372
# on est dans le plot time 1.5209895833322038
# on est dans le plot time 1.5210156249988704
# on est dans le plot time 1.521041666665537
# on est dans le plot time 1.5210677083322037
# on est dans le plot time 1.5210937499988704
# on est dans le plot time 1.521119791665537
# on est dans le plot time 1.5211458333322037
# on est dans le plot time 1.5211718749988703
# on est dans le plot time 1.521197916665537
# on est dans le plot time 1.5212239583322036
# on est dans le plot time 1.5212499999988702
# on est dans le plot time 1.5212760416655369
# on est dans le plot time 1.5213020833322035
# on est dans le plot time 1.5213281249988702
# on est dans le plot time 1.5213541666655368
# on est dans le plot time 1.5213802083322034
# on est dans le plot time 1.52140624999887
# on est dans le plot time 1.5214322916655367
# on est dans le plot time 1.5214583333322034
# on est dans le plot time 1.52148437499887
# on est dans le plot time 1.5215104166655367
# on est dans le plot time 1.5215364583322033
# on est dans le plot time 1.52156249999887
# on est dans le plot time 1.5215885416655366
# on est dans le plot time 1.5216145833322032
# on est dans le plot time 1.5216406249988699
# on est dans le plot time 1.5216666666655365
# on est dans le plot time 1.5216927083322032
# on est dans le plot time 1.5217187499988698
# on est dans le plot time 1.5217447916655364
# on est dans le plot time 1.521770833332203
# on est dans le plot time 1.5217968749988697
# on est dans le plot time 1.5218229166655364
# on est dans le plot time 1.521848958332203
# on est dans le plot time 1.5218749999988697
# on est dans le plot time 1.5219010416655363
# on est dans le plot time 1.521927083332203
# on est dans le plot time 1.5219531249988696
# on est dans le plot time 1.5219791666655362
# on est dans le plot time 1.5220052083322029
# on est dans le plot time 1.5220312499988695
# on est dans le plot time 1.5220572916655362
# on est dans le plot time 1.5220833333322028
# on est dans le plot time 1.5221093749988694
# on est dans le plot time 1.522135416665536
# on est dans le plot time 1.5221614583322027
# on est dans le plot time 1.5221874999988694
# on est dans le plot time 1.522213541665536
# on est dans le plot time 1.5222395833322027
# on est dans le plot time 1.5222656249988693
# on est dans le plot time 1.522291666665536
# on est dans le plot time 1.5223177083322026
# on est dans le plot time 1.5223437499988692
# on est dans le plot time 1.5223697916655359
# on est dans le plot time 1.5223958333322025
# on est dans le plot time 1.5224218749988692
# on est dans le plot time 1.5224479166655358
# on est dans le plot time 1.5224739583322024
# on est dans le plot time 1.522499999998869
# on est dans le plot time 1.5225260416655357
# on est dans le plot time 1.5225520833322024
# on est dans le plot time 1.522578124998869
# on est dans le plot time 1.5226041666655357
# on est dans le plot time 1.5226302083322023
# on est dans le plot time 1.522656249998869
# on est dans le plot time 1.5226822916655356
# on est dans le plot time 1.5227083333322022
# on est dans le plot time 1.5227343749988689
# on est dans le plot time 1.5227604166655355
# on est dans le plot time 1.5227864583322022
# on est dans le plot time 1.5228124999988688
# on est dans le plot time 1.5228385416655355
# on est dans le plot time 1.522864583332202
# on est dans le plot time 1.5228906249988687
# on est dans le plot time 1.5229166666655354
# on est dans le plot time 1.522942708332202
# on est dans le plot time 1.5229687499988687
# on est dans le plot time 1.5229947916655353
# on est dans le plot time 1.523020833332202
# on est dans le plot time 1.5230468749988686
# on est dans le plot time 1.5230729166655352
# on est dans le plot time 1.5230989583322019
# on est dans le plot time 1.5231249999988685
# on est dans le plot time 1.5231510416655352
# on est dans le plot time 1.5231770833322018
# on est dans le plot time 1.5232031249988685
# on est dans le plot time 1.523229166665535
# on est dans le plot time 1.5232552083322017
# on est dans le plot time 1.5232812499988684
# on est dans le plot time 1.523307291665535
# on est dans le plot time 1.5233333333322017
# on est dans le plot time 1.5233593749988683
# on est dans le plot time 1.523385416665535
# on est dans le plot time 1.5234114583322016
# on est dans le plot time 1.5234374999988682
# on est dans le plot time 1.5234635416655349
# on est dans le plot time 1.5234895833322015
# on est dans le plot time 1.5235156249988682
# on est dans le plot time 1.5235416666655348
# on est dans le plot time 1.5235677083322015
# on est dans le plot time 1.523593749998868
# on est dans le plot time 1.5236197916655347
# on est dans le plot time 1.5236458333322014
# on est dans le plot time 1.523671874998868
# on est dans le plot time 1.5236979166655347
# on est dans le plot time 1.5237239583322013
# on est dans le plot time 1.523749999998868
# on est dans le plot time 1.5237760416655346
# on est dans le plot time 1.5238020833322012
# on est dans le plot time 1.5238281249988679
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 795
#     792 # Vérifier si la concentration est supérieure au seuil de sensibilité de la cellule
#     793 if local_camp_concentration >= cell.sensitivity_threshold:
#     794     # La cellule suit le gradient
# --> 795     grad_cAMP = compute_local_gradient(camp_field.signal, cell.position, camp_field.grid_resolution, r_sensing=R_SENSING_GRAD)
#     796     if torch.norm(grad_cAMP) > 0:
#     797         grad_cAMP = grad_cAMP / torch.norm(grad_cAMP)  # Normalisation du gradient
#
# Cell In[5], in compute_local_gradient(signal_grid, position, grid_resolution, r_sensing)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:
